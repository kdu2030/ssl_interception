# %% [markdown]
# # SSL Interception

# %% [markdown]
# ## Set Up

# %%
import pyspark
from pyspark.sql import SparkSession
import pandas as pd
import os
from tldextract import extract
from pandas.core.frame import DataFrame
from pyspark.sql.functions import udf
from pyspark.sql.functions import col
from pyspark.sql.functions import StringType

# %%
import os
import sys

os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable

# %%
SQLContext = SparkSession.builder.master("local[1]") \
                .appName("session-0") \
                .getOrCreate()
# Out:
# 22/11/15 15:20:26 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
#Path to parquet file directory
data = "/mnt/chaseproject/uva/kd5eyn/ssl/2022-02-01/anon.ssl_20220201_0000-0030-0500.log.gz"
#anon.ssl_20220201_0000-0030-0500.log.gz
df = SQLContext.read.parquet(data)
#df = df.filter(df["anon_orig"] == "uva")

# %% [markdown]
# ## Create Whitelist

# %% [markdown]
# * It's unlikely that SSL Interception proxies will use a public trust CA
# * To get a whitelist of public trust CAs, we filter out validation status == OK
# * Then we save the issuer organization

# %%
df.columns
# Out:
# ['_lpp_ver',
#  'anon_orig',
#  'anon_resp',
#  'cert_chain_fuids',
#  'cipher',
#  'client_cert_chain_fuids',
#  'client_issuer',
#  'client_subject',
#  'curve',
#  'established',
#  'id_orig_h',
#  'id_orig_p',
#  'id_resp_h',
#  'id_resp_p',
#  'issuer',
#  'ja3',
#  'ja3s',
#  'last_alert',
#  'next_protocol',
#  'resumed',
#  'server_name',
#  'subject',
#  'ts',
#  'uid',
#  'validation_status',
#  'version']

# %%
def get_issuer_org(issuer_str: str):
    if type(issuer_str) == str:
        o_index = issuer_str.find("O=")
        comma_index = issuer_str.find(",", o_index)
        #Get characters starting from after O= and before ,
        org_str = issuer_str[o_index + 2 :comma_index]
        return org_str.replace("\\", "")

def get_domain(server_name_str: str):
    if type(server_name_str) == str:
        url_parts = extract(server_name_str)
        subdomain = url_parts.subdomain
        domain = url_parts.domain
        #tld - top level domain
        tld = url_parts.suffix
        
        return f"{subdomain}.{domain}.{tld}"

# %%
issuer_org_udf = udf(lambda issuer_str: get_issuer_org(issuer_str), StringType())
domain_udf = udf(lambda server_name: get_domain(server_name), StringType())
df = df.withColumn("issuer_O", issuer_org_udf(col("issuer")))
df = df.withColumn("domain", domain_udf(col("server_name")))

# %%
df_valid = df.filter(df["validation_status"] == "ok")
df_valid = df_valid.dropDuplicates(["issuer_O"])

# %%
df_ok = df_valid.toPandas()
# Out:
# 22/11/15 15:23:04 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.

# %%
df_ok.iloc[1]
# Out:
# _lpp_ver                                                              1.11-2
# anon_orig                                                                uva
# anon_resp                                                               none
# cert_chain_fuids           [FLiwae1ukhOKF8iZi1, Figp3Q3kuoAcFw1PA8, Fuiy7...
# cipher                                 TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# client_cert_chain_fuids                                                   []
# client_issuer                                                           None
# client_subject                                                          None
# curve                                                              secp256r1
# established                                                             True
# id_orig_h                                                     100.157.29.206
# id_orig_p                                                              11032
# id_resp_h                                                     133.223.72.215
# id_resp_p                                                                443
# issuer                     CN=5C75qUejwx 24o 67 1V,O=SecureCore,L=OSAKA,S...
# ja3                                         9f62c4f26b90d3d757bea609e82f2eaf
# ja3s                                        c4b2785a87896e19d37eee932070cb22
# last_alert                                                              None
# next_protocol                                                       http/1.1
# resumed                                                                False
# server_name                                  ep.ww.revuestarlight-relive.com
# subject                                    CN=*.ww.revuestarlight-relive.com
# ts                                               2022-02-01T05:13:24.365564Z
# uid                                                         CkwJgVYfC4C2fjiA
# validation_status                                                         ok
# version                                                               TLSv12
# issuer_O                                                          SecureCore
# domain                                       ep.ww.revuestarlight-relive.com
# Name: 1, dtype: object

# %%
df_ok.head(20)
# Out:
#    _lpp_ver anon_orig anon_resp  \
# 0    1.11-1       uva      none
# 1    1.11-1       uva      none
# 2    1.11-1       uva      none
# 3    1.11-1       uva      none
# 4    1.11-1       uva      none
# 5    1.11-1       uva      none
# 6    1.11-1       uva      none
# 7    1.11-1       uva      none
# 8    1.11-1      none       uva
# 9    1.11-1       uva      none
# 10   1.11-1       uva      none
# 11   1.11-1       uva      none
# 12   1.11-1       uva      none
# 13   1.11-1       uva      none
# 14   1.11-1       uva      none
# 15   1.11-1       uva      none
# 16   1.11-1       uva      none
# 17   1.11-1       uva      none
# 18   1.11-1       uva      none
# 19   1.11-1       uva      none
#
#                                      cert_chain_fuids  \
# 0            [FLhnlK3XKo65ln0Kjf, FqmQAa2RbXnmriGtP1]
# 1            [F3HpUD4wzLgJ5g8HCg, FXFaXv4Il6I3xVhTB6]
# 2            [F6Lksk3RQuLPisw302, FMGHyT3QdM8f06ig3f]
# 3   [Fj6f2W2GHFq98drIMa, FcHjabPniKr6qhvQ7, FYcvh4...
# 4   [FZ7e159zKvBUDPoK3, FWN4FG4TQTeQodUjP7, FsYdly...
# 5            [FTZETr1ZtvG2PRPxU4, F7BQKU3bhDqJjSiVl8]
# 6   [FAshHBkeMi9RHFU81, FfTOqs1KXgjy4IL7W, F2paxeQ...
# 7            [FtuTCf3xJuBy6fwESl, FEBx9E4jSwvpXp66g7]
# 8   [Fzr2jpo32tyeffEI8, FKM8hK2BOLz1AAPTck, FXiiVQ...
# 9   [F7HX6s2fDTKBBDnc7, FNGjfb2KlKpYF7O7G5, FylTAx...
# 10  [Fvp5FA3OhXJ1dCPq0a, FesQmq1Tt01V5p0YCc, FmEbD...
# 11  [FWUzNj2BID03QwTBm1, FSeQwA0AjpF9NAth8, FfoHXe...
# 12  [FBZuOL29If7fwruBWc, F3QYMt1PV0a0ciOcul, FIGfM...
# 13            [F6Wec9zHPsJH0Exsb, FLJwqG4ZjqlNjfLk3a]
# 14  [FBQk6ZoHbnoE6GW5d, FawvXN1a5dHwcCnAtl, F9VQd7...
# 15           [Fkz6gZ1kHmxBN7FHOa, FYdRv64Lo8uumBpez9]
# 16           [FV8cC63JV3ztNHIDD3, FWMepk2z3bTyc0vni8]
# 17            [Fep8lc4inRKnMMz9pl, FNmR4AzVdvnW8pq0c]
# 18  [FwK6S82IO5weEqh0r4, F8TJmk2S9J6F6RW8I7, FJKHm...
# 19           [FhKSaX3v7932uAs38j, FLyG2B12FRFjvqdUQ6]
#
#                                      cipher client_cert_chain_fuids  \
# 0     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 1        TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA                      []
# 2     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 3     TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 4     TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 5     TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 6     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 7     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 8       TLS_DHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 9     TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 10    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 11    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 12          TLS_RSA_WITH_AES_256_CBC_SHA256                      []
# 13    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 14    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 15    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 16  TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 17    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 18    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 19    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
#
#    client_issuer client_subject      curve  established  ... next_protocol  \
# 0           None           None     x25519         True  ...            h2
# 1           None           None  secp256r1         True  ...          None
# 2           None           None  secp256r1         True  ...          None
# 3           None           None     x25519         True  ...          None
# 4           None           None  secp256r1         True  ...          None
# 5           None           None  secp256r1         True  ...          None
# 6           None           None     x25519         True  ...            h2
# 7           None           None  secp256r1         True  ...      http/1.1
# 8           None           None       None         True  ...      http/1.1
# 9           None           None     x25519         True  ...          None
# 10          None           None  secp256r1         True  ...          None
# 11          None           None  secp256r1         True  ...            h2
# 12          None           None       None        False  ...      http/1.1
# 13          None           None     x25519         True  ...          None
# 14          None           None  secp521r1         True  ...          None
# 15          None           None  secp256r1         True  ...      http/1.1
# 16          None           None  secp256r1         True  ...      http/1.1
# 17          None           None  secp256r1         True  ...          None
# 18          None           None     x25519         True  ...      http/1.1
# 19          None           None  secp256r1         True  ...          None
#
#     resumed                             server_name  \
# 0     False                             us.puma.com
# 1     False               www.enable-javascript.com
# 2     False  digital-eum-appdynamics.wellsfargo.com
# 3     False            mattermost.mpifr-bonn.mpg.de
# 4     False                     sync6.omnigroup.com
# 5     False                    perfsonar.nci.org.au
# 6     False                             zworker7.me
# 7     False            takedown.api.playstation.com
# 8     False                   47eGcmVz.virginia.edu
# 9     False                    pixel.onaudience.com
# 10    False                                s.360.cn
# 11    False                              thrtle.com
# 12    False                      idbroker.webex.com
# 13    False               lfodown01-b.cloudsink.net
# 14    False                                    None
# 15    False                            c.apple.news
# 16    False                              github.com
# 17    False                 protected-by.clarium.io
# 18    False                         x.bidswitch.net
# 19    False                           boa.unimib.it
#
#                                               subject  \
# 0   CN=us.puma.com,O=PUMA SE,OU=Global E-Commerce,...
# 1                            CN=enable-javascript.com
# 2   CN=prod-eum-appdynamics.wellsfargo.com,O=Wells...
# 3   CN=mattermost.mpifr-bonn.mpg.de,OU=Max-Planck-...
# 4                              CN=sync6.omnigroup.com
# 5   CN=perfsonar.nci.org.au,O=Australian National ...
# 6                                      CN=zworker7.me
# 7                            CN=*.api.playstation.com
# 8                            CN=47eGcmVz.virginia.edu
# 9                                 CN=*.onaudience.com
# 10  CN=*.s.360.cn,O=Beijing Qihoo Technology Compa...
# 11        CN=*.thrtle.com,OU=Domain Control Validated
# 12                                               None
# 13  CN=ts01-b.cloudsink.net,O=CrowdStrike\, Inc.,L...
# 14  CN=ecccp.amer.pub.webex.com,O=Cisco Systems\, ...
# 15  C=US,ST=California,O=Apple Inc.,OU=management:...
# 16  CN=github.com,O=GitHub\, Inc.,L=San Francisco,...
# 17                         CN=protected-by.clarium.io
# 18                                 CN=*.bidswitch.net
# 19  CN=boa.unimib.it,OU=Area Ricerca,O=Universit\C...
#
#                              ts                 uid validation_status version  \
# 0   2021-12-28T14:54:54.970484Z  CHYoYS1Xj6HfVIDGOh                ok  TLSv12
# 1   2021-12-28T14:46:28.778130Z  CvrlIv2Xvwv8YAIp89                ok  TLSv12
# 2   2021-12-28T14:44:23.780893Z  CFVCco2d1Xm8qQX611                ok  TLSv12
# 3   2021-12-28T14:46:00.085830Z  C6ccee2sDJA3N7cq5j                ok  TLSv12
# 4   2021-12-28T14:44:25.751412Z  CjgZDq2yrUF4eUy59l                ok  TLSv12
# 5   2021-12-28T14:49:38.746086Z   CGL0manmvAE9HZ92j                ok  TLSv12
# 6   2021-12-28T14:44:22.113212Z  CgyQHl1IJuhcOglzDi                ok  TLSv12
# 7   2021-12-28T14:45:10.928183Z   ClWrlFv9XxSzi8zxa                ok  TLSv12
# 8   2021-12-28T14:45:03.342702Z  CCzrit3xWJ40m4P9C5                ok  TLSv12
# 9   2021-12-28T14:46:12.777290Z  C77HwU2F7Y7ydTGZQl                ok  TLSv12
# 10  2021-12-28T14:38:40.523431Z  Cf1Web1xyt1LFKsaPl                ok  TLSv12
# 11  2021-12-28T14:44:21.644864Z  CbBgqS2cI60SM10olk                ok  TLSv12
# 12  2021-12-28T14:29:54.879903Z  CkAkln2uAe7CKDAgkc                ok  TLSv12
# 13  2021-12-28T14:35:57.261243Z  CttgDk314TYf8rAYP8                ok  TLSv12
# 14  2021-12-28T14:44:23.605899Z  CjZTvD3snPnFmRodIe                ok  TLSv12
# 15  2021-12-28T14:44:21.951363Z  C7VqWY1V0ME3TpGMaj                ok  TLSv12
# 16  2021-12-28T14:30:02.389451Z  Czi3B43Wlzn1rCBwrc                ok  TLSv12
# 17  2021-12-28T14:44:23.047936Z  CitsVf2mPeJ9F9QHFe                ok  TLSv12
# 18  2021-12-28T14:44:21.827065Z  CTibxm21RBWmUx59Ji                ok  TLSv12
# 19  2021-12-28T14:52:15.030909Z  CD2tz93nXlT5Q5WyS1                ok  TLSv12
#
#                                    issuer_O  \
# 0                              D-Trust GmbH
# 1                       DOMENY.PL sp. z o.o
# 2                     Wells Fargo & Company
# 3                   Max-Planck-Gesellschaft
# 4                                   ZeroSSL
# 5                          QuoVadis Limited
# 6                             Let's Encrypt
# 7                              Comodo Japan
# 8                                    cPanel
# 9                              home.pl S.A.
# 10                        WoSign CA Limited
# 11                              GoDaddy.com
# 12                                     None
# 13                              CrowdStrike
# 14  HydrantID (Avalanche Cloud Corporation)
# 15                               Apple Inc.
# 16                                 DigiCert
# 17                                    Gandi
# 18                          Sectigo Limited
# 19                                   TERENA
#
#                                     domain
# 0                              us.puma.com
# 1                www.enable-javascript.com
# 2   digital-eum-appdynamics.wellsfargo.com
# 3             mattermost.mpifr-bonn.mpg.de
# 4                      sync6.omnigroup.com
# 5                     perfsonar.nci.org.au
# 6                             .zworker7.me
# 7             takedown.api.playstation.com
# 8                    47eGcmVz.virginia.edu
# 9                     pixel.onaudience.com
# 10                                s.360.cn
# 11                             .thrtle.com
# 12                      idbroker.webex.com
# 13               lfodown01-b.cloudsink.net
# 14                                    None
# 15                            c.apple.news
# 16                             .github.com
# 17                 protected-by.clarium.io
# 18                         x.bidswitch.net
# 19                           boa.unimib.it
#
# [20 rows x 28 columns]

# %%
#df_ok = df[df["validation_status"] == "ok"]
df_orgs = df_ok.groupby(["issuer_O"])["server_name"].agg("count").reset_index(name="count")
df_orgs.head(10)
# Out:
#                                   issuer_O  count
# 0                                Aetna Inc      1
# 1                              AffirmTrust      1
# 2                                   Amazon      1
# 3                               Apple Inc.      1
# 4                        COMODO CA Limited      1
# 5            CentralNic Luxembourg SC3A0rl      1
# 6  China Financial Certification Authority      1
# 7                               Cloudflare      1
# 8                             Comodo Japan      1
# 9              Corporation Service Company      1

# %%
def gen_whitelist(whitelist_path: str, df_orgs: pd.core.frame.DataFrame):
    whitelist_file = open(whitelist_path, "r+")
    whitelist_orgs = set(whitelist_file.read().splitlines())
    for org in df_orgs["issuer_O"]:
        if org not in whitelist_orgs:
            whitelist_orgs.add(org)
            whitelist_file.write(org + "\n")
    whitelist_file.close()
    return whitelist_orgs

# %%
def get_list_set(file_path: str) -> set:
    file = open(file_path, "r")
    return set(file.read().splitlines())

# %%
whitelist = gen_whitelist("whitelist.txt", df_orgs)

# %% [markdown]
# ## Parse for Unable to Get Local Certificate

# %%
df_unable = df.filter(df.validation_status == "unable to get local issuer certificate")
df_unable = df_unable.groupBy(["domain", "issuer_O"]).count()
df_unable.count()
# Out:
# 440

# %%
df_unable = df_unable.toPandas()
df_unable
# Out:
#                                     domain  \
# 0                p57-fmipmobile.icloud.com
# 1                                     None
# 2                sfd.et1240.epichosted.com
# 3            instantnews.huub.sliide.cloud
# 4                    wdcpalt.microsoft.com
# ..                                     ...
# 435  array510.prod.do.dsp.mp.microsoft.com
# 436                    bmecmg.cloudapp.net
# 437           cehcahealthcare.stdavids.com
# 438                 devops.shottracker.com
# 439                                   None
#
#                                               issuer_O  count
# 0                                           Apple Inc.      1
# 1                                                 eYou      1
# 2                                           EMR Direct      1
# 3                                               Sliide      3
# 4                                Microsoft Corporation      5
# ..                                                 ...    ...
# 435                              Microsoft Corporation   1192
# 436        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 437                                         EMR Direct      2
# 438  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
# 439                                      RICOH COMPANY     65
#
# [440 rows x 3 columns]

# %%
blacklist_url = "blacklist.txt"
blacklist = get_list_set(blacklist_url)
blacklist
# Out:
# {'Alleghany County Public Schools',
#  'BAYER',
#  'Barracuda Networks',
#  'Boston Scientific Corporation',
#  'Charlotte County Public Schools',
#  'Cisco',
#  'Cisco Systems',
#  'Cisco Systems\\',
#  'FIREEYE',
#  'Forcepoint LLC',
#  'Fortinet',
#  'Freddie Mac',
#  'General Electric Company',
#  'Hanover County Public Schools',
#  'Harrisonburg City Public Schools',
#  'Henrico County Public Schools',
#  'Johnson Controls International PLC',
#  'Kaspersky',
#  'Kaspersky Lab',
#  'LOCKSS box',
#  'McKesson Corporation',
#  'Menlo Security Inc.',
#  'Private Internet Access',
#  'SaferNet',
#  'Technicolor',
#  'Toyota North America',
#  'Zscaler Inc.',
#  'Zscaler\\',
#  'cisco',
#  'iboss Network Security'}

# %%
df_filtered = df_unable[~(df_unable["issuer_O"].isin(whitelist) | df_unable["issuer_O"].isin(blacklist))]

# %%
df_filtered = df_filtered[df_filtered["domain"].str.contains("None") == False]
df_filtered = df_filtered[df_filtered["issuer_O"].str.contains("None") == False]
df_filtered
# Out:
#                             domain  \
# 2        sfd.et1240.epichosted.com
# 3    instantnews.huub.sliide.cloud
# 7        sfd.et1146.epichosted.com
# 16                ceprd.sjhsyr.org
# 21                sfprod.acpny.com
# ..                             ...
# 430    carequality.crisphealth.org
# 431          US.info.lgsmartad.com
# 436            bmecmg.cloudapp.net
# 437   cehcahealthcare.stdavids.com
# 438         devops.shottracker.com
#
#                                               issuer_O  count
# 2                                           EMR Direct      1
# 3                                               Sliide      3
# 7                                           EMR Direct      1
# 16                                          EMR Direct      2
# 21                                          EMR Direct      1
# ..                                                 ...    ...
# 430                                         EMR Direct      1
# 431                                LG Electronics Inc.      1
# 436        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 437                                         EMR Direct      2
# 438  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
#
# [145 rows x 3 columns]

# %%
def is_selfsigned(domain: str, issuer_O: str) -> bool:
    domain_lower = extract(domain.lower()).domain
    issuer_lower = issuer_O.lower().replace(" ", "")
    return domain_lower in issuer_lower

# %%
df_not_selfsigned = df_filtered[~df_filtered.apply(lambda x: is_selfsigned(x["domain"], x["issuer_O"]), axis=1)]
df_not_selfsigned.reset_index(inplace=True)
df_not_selfsigned = df_not_selfsigned.drop("index", axis=1)
df_not_selfsigned
# Out:
#                            domain  \
# 0       sfd.et1240.epichosted.com
# 1       sfd.et1146.epichosted.com
# 2                ceprd.sjhsyr.org
# 3                sfprod.acpny.com
# 4                   ce.chppoc.org
# ..                            ...
# 104   carequality.crisphealth.org
# 105         US.info.lgsmartad.com
# 106           bmecmg.cloudapp.net
# 107  cehcahealthcare.stdavids.com
# 108        devops.shottracker.com
#
#                                               issuer_O  count
# 0                                           EMR Direct      1
# 1                                           EMR Direct      1
# 2                                           EMR Direct      2
# 3                                           EMR Direct      1
# 4                                           EMR Direct      1
# ..                                                 ...    ...
# 104                                         EMR Direct      1
# 105                                LG Electronics Inc.      1
# 106        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 107                                         EMR Direct      2
# 108  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
#
# [109 rows x 3 columns]

# %% [markdown]
# # Virus Total API Data Exploration

# %% [markdown]
# * Virus Total has information about HTTPS certificates
# * Check if Logged Certificate Organization matches one that Virus Total
# * If they don't match, may be SSL interception because Virus Total information may be outdated

# %%
import vt
api_key_file = open("/home/ubuntu/GitLab/ssl_interception/virus_total_api_key", "r")
api_key = api_key_file.readline()
api_key_file.close()

# %%
client = vt.Client(api_key)
url_id = vt.url_id("http://dbankcloud.asia")

# %%
import nest_asyncio
nest_asyncio.apply()
#url = client.scan_url("http://dbankcloud.asia")
#url = client.get_object("/domains/{}/historical_whois", "dbankcloud.asia")
try:
    data = client.get_data("/domains/dbankcloud.asia/historical_whois")
except as E
#url
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 5>()
#       2 nest_asyncio.apply()
#       3 #url = client.scan_url("http://dbankcloud.asia")
#       4 #url = client.get_object("/domains/{}/historical_whois", "dbankcloud.asia")
# ----> 5 data = client.get_data("/domains/dbankcloud.asia/historical_whois")
#
# File ~/.local/lib/python3.8/site-packages/vt/client.py:461, in Client.get_data(self, path, params, *path_args)
#     438 def get_data(self, path, *path_args, params=None):
#     439   """Sends a GET request to a given API endpoint and returns response's data.
#     440
#     441   Most VirusTotal API responses are JSON-encoded with the following format::
#    (...)
#     459     called.
#     460   """
# --> 461   return make_sync(self.get_data_async(path, *path_args, params=params))
#
# File ~/.local/lib/python3.8/site-packages/vt/utils.py:27, in make_sync(future)
#      25   event_loop = asyncio.new_event_loop()
#      26   asyncio.set_event_loop(event_loop)
# ---> 27 return event_loop.run_until_complete(future)
#
# File ~/.local/lib/python3.8/site-packages/nest_asyncio.py:81, in _patch_loop.<locals>.run_until_complete(self, future)
#      78 if not f.done():
#      79     raise RuntimeError(
#      80         'Event loop stopped before Future completed.')
# ---> 81 return f.result()
#
# File /usr/lib/python3.8/asyncio/futures.py:178, in Future.result(self)
#     176 self.__log_traceback = False
#     177 if self._exception is not None:
# --> 178     raise self._exception
#     179 return self._result
#
# File /usr/lib/python3.8/asyncio/tasks.py:280, in Task.__step(***failed resolving arguments***)
#     276 try:
#     277     if exc is None:
#     278         # We use the `send` method directly, because coroutines
#     279         # don't have `__iter__` and `__next__` methods.
# --> 280         result = coro.send(None)
#     281     else:
#     282         result = coro.throw(exc)
#
# File ~/.local/lib/python3.8/site-packages/vt/client.py:465, in Client.get_data_async(self, path, params, *path_args)
#     463 async def get_data_async(self, path, *path_args, params=None):
#     464   """Like :func:`get_data` but returns a coroutine."""
# --> 465   json_response = await self.get_json_async(path, *path_args, params=params)
#     466   return self._extract_data_from_json(json_response)
#
# File ~/.local/lib/python3.8/site-packages/vt/client.py:509, in Client.get_json_async(self, path, params, *path_args)
#     507 """Like :func:`get_json` but returns a coroutine."""
#     508 response = await self.get_async(path, *path_args, params=params)
# --> 509 return await self._response_to_json(response)
#
# File ~/.local/lib/python3.8/site-packages/vt/client.py:273, in Client._response_to_json(self, response)
#     271 error = await self.get_error_async(response)
#     272 if error:
# --> 273   raise error
#     274 return await response.json_async()
#
# APIError: ('QuotaExceededError', 'Quota exceeded')

# %%
data[0]["attributes"]["whois_map"]["Name Server"]
# Out:
# 'GNS1.HUAWEICLOUD-DNS.CN | GNS1.HUAWEICLOUD-DNS.COM | GNS1.HUAWEICLOUD-DNS.ORG | NS3.DNSV5.COM | NS4.DNSV5.COM'

# %%
data_cas = client.get_data("/domains/hhchealth.org/historical_ssl_certificates")

# %%
data_cas
# Out:
# [{'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1652282289,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert TLS RSA SHA256 2020 CA1',
#     'O': 'DigiCert Inc'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '0e2bf9ab4796b5d6ef2347130b3c91e7',
#    'validity': {'not_after': '2022-11-12 23:59:59',
#     'not_before': '2022-04-28 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': 'b76ba2eaa8aa848c79eab4da0f98b2c59576b9f4'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'give.stvincents.org',
#      'middlesexcardiology.com',
#      'www.hartfordhospital.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'www.hartfordhealthcarebhn.org',
#      'www.middlesexcardiology.com',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org',
#      'www.healthnewshub.org',
#      'healthnewshub.org',
#      'www.cardiologypcofhartford.com',
#      'cardiologypcofhartford.com',
#      'cottagegrovecardiology.com',
#      'hartfordhealthcarebhn.org',
#      'news.hartfordhealthcare.org',
#      'stvincents.org',
#      'thocc.org',
#      'www.cottagegrovecardiology.com',
#      'hartfordhealthcare.org',
#      'hospicesect.org',
#      'www.hospicesect.org'],
#     'tags': [],
#     'subject_key_identifier': 'e1880ebfa7429d99b6e5402819f4c79a0d73ccd2',
#     'crl_distribution_points': ['http://crl3.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl',
#      'http://crl4.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0482016a01680076002979bef09e393921f056739f63a577e5be577d9c600af8',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertTLSRSASHA2562020CA1-1.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': '61d469de77a07781b44f57f65f700ec218c1920b45522183f0dbe750758df0b3',
#    'thumbprint': '85dd17e40c5ee6f66eb960c621ceb18d1f1b0383',
#    'size': 3376,
#    'subject': {'C': 'US',
#     'ST': 'Connecticut',
#     'CN': '*.hartfordhealthcare.org',
#     'O': 'Hartford Healthcare Corporation',
#     'L': 'Hartford'}},
#   'type': 'ssl_cert',
#   'id': '61d469de77a07781b44f57f65f700ec218c1920b45522183f0dbe750758df0b3',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/61d469de77a07781b44f57f65f700ec218c1920b45522183f0dbe750758df0b3'},
#   'context_attributes': {'first_seen_date': '2022-05-11', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1649390657,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert TLS RSA SHA256 2020 CA1',
#     'O': 'DigiCert Inc'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': 'e2c15abd6bf8b885da1e3b0f81541c1',
#    'validity': {'not_after': '2022-11-12 23:59:59',
#     'not_before': '2022-04-07 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': 'b76ba2eaa8aa848c79eab4da0f98b2c59576b9f4'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'give.stvincents.org',
#      'middlesexcardiology.com',
#      'www.hartfordhospital.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'www.hartfordhealthcarebhn.org',
#      'www.middlesexcardiology.com',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org',
#      'www.healthnewshub.org',
#      'healthnewshub.org',
#      'www.cardiologypcofhartford.com',
#      'cardiologypcofhartford.com',
#      'cottagegrovecardiology.com',
#      'hartfordhealthcarebhn.org',
#      'news.hartfordhealthcare.org',
#      'stvincents.org',
#      'thocc.org',
#      'www.cottagegrovecardiology.com',
#      'hartfordhealthcare.org'],
#     'tags': [],
#     'subject_key_identifier': '4b39259fcc955ba28092f45f29abe5dcf2f7f1cb',
#     'crl_distribution_points': ['http://crl3.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl',
#      'http://crl4.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '04820169016700770046a555eb75fa912030b5a28969f4f37d112c4174befd49',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertTLSRSASHA2562020CA1-1.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': 'c2c0c12a626a2fb6566207e9eb5a3eef3aa1633b46456a5ec3b17e38a98865c3',
#    'thumbprint': '667d991db83312f51ea74e2e7ac45e05dd532df3',
#    'size': 3337,
#    'subject': {'C': 'US',
#     'ST': 'Connecticut',
#     'CN': '*.hartfordhealthcare.org',
#     'O': 'Hartford Healthcare Corporation',
#     'L': 'Hartford'}},
#   'type': 'ssl_cert',
#   'id': 'c2c0c12a626a2fb6566207e9eb5a3eef3aa1633b46456a5ec3b17e38a98865c3',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/c2c0c12a626a2fb6566207e9eb5a3eef3aa1633b46456a5ec3b17e38a98865c3'},
#   'context_attributes': {'first_seen_date': '2022-04-08', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1641327942,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert TLS RSA SHA256 2020 CA1',
#     'O': 'DigiCert Inc'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '98a77e64308fceb63348174bc8e34a8',
#    'validity': {'not_after': '2022-11-12 23:59:59',
#     'not_before': '2021-12-28 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': 'b76ba2eaa8aa848c79eab4da0f98b2c59576b9f4'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'www.hartfordhealthcarebhn.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hartfordhospital.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org',
#      'thocc.org',
#      'stvincents.org',
#      'give.stvincents.org',
#      'cottagegrovecardiology.com',
#      'www.cottagegrovecardiology.com',
#      'HighRidgeFamilyPractice.com',
#      'www.HighRidgeFamilyPractice.com',
#      'www.middlesexcardiology.com',
#      'middlesexcardiology.com'],
#     'tags': [],
#     'subject_key_identifier': '4500b1858c437bec8111520c0045ccc6a708f311',
#     'crl_distribution_points': ['http://crl3.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl',
#      'http://crl4.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0482016a016800750046a555eb75fa912030b5a28969f4f37d112c4174befd49',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertTLSRSASHA2562020CA1-1.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': '682c802ae6cea07274fe8ee1865f192158d856c58a1f9f48bda7068056ce84f9',
#    'thumbprint': 'ba9a821b2352c1ffa4c4e58f9948bab8ea474147',
#    'size': 3272,
#    'subject': {'C': 'US',
#     'ST': 'Connecticut',
#     'CN': '*.hartfordhealthcare.org',
#     'O': 'Hartford Healthcare Corporation',
#     'L': 'Hartford'}},
#   'type': 'ssl_cert',
#   'id': '682c802ae6cea07274fe8ee1865f192158d856c58a1f9f48bda7068056ce84f9',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/682c802ae6cea07274fe8ee1865f192158d856c58a1f9f48bda7068056ce84f9'},
#   'context_attributes': {'first_seen_date': '2022-01-04', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1634223451,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert TLS RSA SHA256 2020 CA1',
#     'O': 'DigiCert Inc'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '23e032eb98e1189b81f443dd22b1eca',
#    'validity': {'not_after': '2022-11-12 23:59:59',
#     'not_before': '2021-10-12 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': 'b76ba2eaa8aa848c79eab4da0f98b2c59576b9f4'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'www.hartfordhealthcarebhn.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hartfordhospital.org',
#      'www.healthnewshub.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org',
#      'thocc.org',
#      'stvincents.org',
#      'give.stvincents.org',
#      'cottagegrovecardiology.com',
#      'www.cottagegrovecardiology.com'],
#     'tags': [],
#     'subject_key_identifier': 'd9dc3d4c83c5e667be9a3862c41f9ee55cf92f05',
#     'crl_distribution_points': ['http://crl3.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl',
#      'http://crl4.digicert.com/DigiCertTLSRSASHA2562020CA1-4.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0482016b016900770046a555eb75fa912030b5a28969f4f37d112c4174befd49',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertTLSRSASHA2562020CA1-1.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': 'd13592d9e50a60057e833d2b8169c846442b2d559228195751ca6d792167b7cf',
#    'thumbprint': '61c4b24adf821de5c6e0cd26f1999907c9ecdaea',
#    'size': 3199,
#    'subject': {'C': 'US',
#     'ST': 'Connecticut',
#     'CN': '*.hartfordhealthcare.org',
#     'O': 'Hartford Healthcare Corporation',
#     'L': 'Hartford'}},
#   'type': 'ssl_cert',
#   'id': 'd13592d9e50a60057e833d2b8169c846442b2d559228195751ca6d792167b7cf',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/d13592d9e50a60057e833d2b8169c846442b2d559228195751ca6d792167b7cf'},
#   'context_attributes': {'first_seen_date': '2021-10-15', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1633667162,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert SHA2 High Assurance Server CA',
#     'O': 'DigiCert Inc',
#     'OU': 'www.digicert.com'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '4dadbd2519b51ccd55109a9584bb0be',
#    'validity': {'not_after': '2022-07-29 23:59:59',
#     'not_before': '2021-10-05 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': '5168ff90af0207753cccd9656462a212b859723b'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'www.hartfordhealthcarebhn.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'thocc.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'stvincents.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'give.stvincents.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhospital.org',
#      'www.healthnewshub.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org'],
#     'tags': [],
#     'subject_key_identifier': '2e39555f72ea770519ff5bf60610d6e2520a9ef1',
#     'crl_distribution_points': ['http://crl3.digicert.com/sha2-ha-server-g6.crl',
#      'http://crl4.digicert.com/sha2-ha-server-g6.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '04820169016700760046a555eb75fa912030b5a28969f4f37d112c4174befd49',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertSHA2HighAssuranceServerCA.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': '130c09227d3c14bb31696a2394df3a61bad54b36d64659cc6622a91054f8ae1d',
#    'thumbprint': '29fe561144b9e775dd4ab4683ace79c29a7fb611',
#    'size': 3105,
#    'subject': {'C': 'US',
#     'CN': '*.hartfordhealthcare.org',
#     'L': 'Hartford',
#     'O': 'Hartford Healthcare Corporation',
#     'ST': 'Connecticut',
#     'OU': 'Information Technology'}},
#   'type': 'ssl_cert',
#   'id': '130c09227d3c14bb31696a2394df3a61bad54b36d64659cc6622a91054f8ae1d',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/130c09227d3c14bb31696a2394df3a61bad54b36d64659cc6622a91054f8ae1d'},
#   'context_attributes': {'first_seen_date': '2021-10-12', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1628338937,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert SHA2 Secure Server CA',
#     'O': 'DigiCert Inc'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '5d50323e675a311863951db76e8694e',
#    'validity': {'not_after': '2021-10-10 23:59:59',
#     'not_before': '2021-08-03 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': '0f80611c823161d52f28e78d4638b42ce1c6d9e2'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'thocc.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'stvincents.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'give.stvincents.org',
#      'swimacrossthesound.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'cottagegrovecardiology.com',
#      'www.hartfordhealthcarebhn.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.swimacrossthesound.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hartfordhospital.org',
#      'www.healthnewshub.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'www.cottagegrovecardiology.com',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org'],
#     'tags': [],
#     'subject_key_identifier': 'bfe180786392561a52dbbb7137978b80f544b5c9',
#     'crl_distribution_points': ['http://crl3.digicert.com/DigiCertSHA2SecureServerCA.crl',
#      'http://crl4.digicert.com/DigiCertSHA2SecureServerCA.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '048201690167007600f65c942fd1773022145418083094568ee34d131933bfdf',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertSHA2SecureServerCA-2.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': '4285df6a92503140d2e1487b57f0a43bc4375892a40123bffd2679074bd198a1',
#    'thumbprint': 'b2f0f4403c9e7511d81f32b12ec544aa29116aa5',
#    'size': 3272,
#    'subject': {'C': 'US',
#     'CN': '*.hartfordhealthcare.org',
#     'L': 'Hartford',
#     'O': 'Hartford Healthcare Corporation',
#     'ST': 'Connecticut',
#     'OU': 'Information Technology'}},
#   'type': 'ssl_cert',
#   'id': '4285df6a92503140d2e1487b57f0a43bc4375892a40123bffd2679074bd198a1',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/4285df6a92503140d2e1487b57f0a43bc4375892a40123bffd2679074bd198a1'},
#   'context_attributes': {'first_seen_date': '2021-08-14', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1613714596,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert SHA2 High Assurance Server CA',
#     'O': 'DigiCert Inc',
#     'OU': 'www.digicert.com'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '8dd9aa47c43e66c9ebb4a8fb9b54130',
#    'validity': {'not_after': '2021-10-09 23:59:59',
#     'not_before': '2021-02-18 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': '5168ff90af0207753cccd9656462a212b859723b'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'www.hartfordhealthcarebhn.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'thocc.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'stvincents.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'give.stvincents.org',
#      'swimacrossthesound.org',
#      'ctorthomidstate.org',
#      'ctorthostvincents.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.swimacrossthesound.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hartfordhospital.org',
#      'www.healthnewshub.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'www.ctorthomidstate.org',
#      'www.ctorthostvincents.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org'],
#     'tags': [],
#     'subject_key_identifier': '3dd315ae425aea4768a59734460609f7c70ae31f',
#     'crl_distribution_points': ['http://crl3.digicert.com/sha2-ha-server-g6.crl',
#      'http://crl4.digicert.com/sha2-ha-server-g6.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0481f200f0007600f65c942fd1773022145418083094568ee34d131933bfdf0c',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertSHA2HighAssuranceServerCA.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': 'df1c475499118645c0ab6dfdfd02c4ecdfe77f0175c2e6ab24cd65fc162ca51f',
#    'thumbprint': 'add4cd68a8a97c5e00aedcf9e431cd85b06f0047',
#    'size': 3112,
#    'subject': {'C': 'US',
#     'CN': '*.hartfordhealthcare.org',
#     'L': 'Hartford',
#     'O': 'Hartford Healthcare Corporation',
#     'ST': 'Connecticut',
#     'OU': 'Information Technology'}},
#   'type': 'ssl_cert',
#   'id': 'df1c475499118645c0ab6dfdfd02c4ecdfe77f0175c2e6ab24cd65fc162ca51f',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/df1c475499118645c0ab6dfdfd02c4ecdfe77f0175c2e6ab24cd65fc162ca51f'},
#   'context_attributes': {'first_seen_date': '2021-02-19', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1603121816,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert SHA2 High Assurance Server CA',
#     'O': 'DigiCert Inc',
#     'OU': 'www.digicert.com'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': 'c9b955b8c56d6bc13428d693e65b377',
#    'validity': {'not_after': '2021-10-10 12:00:00',
#     'not_before': '2020-10-07 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.16.840.1.114412.1.1',
#      '2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': '5168ff90af0207753cccd9656462a212b859723b'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'www.hartfordhealthcarebhn.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'thocc.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'stvincents.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'stvincentsspecialneeds.org',
#      'give.stvincents.org',
#      'swimacrossthesound.org',
#      'www.Backushospital.org',
#      'www.stvincentsspecialneeds.org',
#      'www.swimacrossthesound.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hartfordhospital.org',
#      'www.healthnewshub.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org'],
#     'tags': [],
#     'subject_key_identifier': 'da7e954b45d24cd1468c26ade6d5106a13ac5967',
#     'crl_distribution_points': ['http://crl3.digicert.com/sha2-ha-server-g6.crl',
#      'http://crl4.digicert.com/sha2-ha-server-g6.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0481f300f10076007d3ef2f88fff88556824c2c0ca9e5289792bc50e78097f2e',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertSHA2HighAssuranceServerCA.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': '21b93dc3e8b7d9a89412a1d18c888e56d4c42395bae92530387f46f65efe0d80',
#    'thumbprint': 'f90622ec55c0c720fa3f7b3326af132c67a2a173',
#    'size': 3031,
#    'subject': {'C': 'US',
#     'CN': '*.hartfordhealthcare.org',
#     'L': 'Hartford',
#     'O': 'Hartford Healthcare Corporation',
#     'ST': 'Connecticut',
#     'OU': 'Information Technology'}},
#   'type': 'ssl_cert',
#   'id': '21b93dc3e8b7d9a89412a1d18c888e56d4c42395bae92530387f46f65efe0d80',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/21b93dc3e8b7d9a89412a1d18c888e56d4c42395bae92530387f46f65efe0d80'},
#   'context_attributes': {'first_seen_date': '2020-10-19', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1592999752,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert SHA2 High Assurance Server CA',
#     'O': 'DigiCert Inc',
#     'OU': 'www.digicert.com'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '68a7c3bfc63a68dd86c1dd542798804',
#    'validity': {'not_after': '2022-07-29 12:00:00',
#     'not_before': '2020-06-22 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.16.840.1.114412.1.1',
#      '2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': '5168ff90af0207753cccd9656462a212b859723b'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      '*.hhchealth.org',
#      'hartfordhealthcare.org',
#      'hartfordhospital.org',
#      'thocc.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'stvincents.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'www.Backushospital.org',
#      'www.charlottehungerford.org',
#      'www.ctorthoinstitute.org',
#      'www.hartfordhealthcareathome.org',
#      'www.hartfordhealthcarebhn.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.hartfordhospital.org',
#      'www.healthnewshub.org',
#      'www.hhcbehavioralhealth.org',
#      'www.hhcconnect.org',
#      'www.hhcseniorservices.org',
#      'www.instituteofliving.org',
#      'www.integratedcarepartners.org',
#      'www.midstatemedical.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.stvincents.org',
#      'www.thocc.org',
#      'www.windhamhospital.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org',
#      'hhchealth.org'],
#     'tags': [],
#     'subject_key_identifier': '621a1c09f3c84f44dd5bd51b60d42b8414e992bc',
#     'crl_distribution_points': ['http://crl3.digicert.com/sha2-ha-server-g6.crl',
#      'http://crl4.digicert.com/sha2-ha-server-g6.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0482016c016a0077002979bef09e393921f056739f63a577e5be577d9c600af8',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertSHA2HighAssuranceServerCA.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': '8184755589a8d3fceb37f53242d82c137148f0fac3c6a592ad2915166ca42c7d',
#    'thumbprint': 'f7e9ac61174478bcc7d3d51e250ae90b0f7e3483',
#    'size': 3038,
#    'subject': {'C': 'US',
#     'CN': '*.hartfordhealthcare.org',
#     'L': 'Hartford',
#     'O': 'Hartford Healthcare Corporation',
#     'ST': 'Connecticut',
#     'OU': 'Information Technology'}},
#   'type': 'ssl_cert',
#   'id': '8184755589a8d3fceb37f53242d82c137148f0fac3c6a592ad2915166ca42c7d',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/8184755589a8d3fceb37f53242d82c137148f0fac3c6a592ad2915166ca42c7d'},
#   'context_attributes': {'first_seen_date': '2020-06-30', 'port': '443'}},
#  {'attributes': {'public_key': {'rsa': {'key_size': 2048,
#      'modulus': '...',
#      'exponent': '010001'},
#     'algorithm': 'RSA'},
#    'first_seen_date': 1590014349,
#    'issuer': {'C': 'US',
#     'CN': 'DigiCert SHA2 High Assurance Server CA',
#     'O': 'DigiCert Inc',
#     'OU': 'www.digicert.com'},
#    'cert_signature': {'signature': '...',
#     'signature_algorithm': 'sha256RSA'},
#    'serial_number': '3722a2f13d2bf00c05788de91d9aa79',
#    'validity': {'not_after': '2020-06-24 12:00:00',
#     'not_before': '2020-05-20 00:00:00'},
#    'version': 'V3',
#    'extensions': {'certificate_policies': ['2.16.840.1.114412.1.1',
#      '2.23.140.1.2.2'],
#     'extended_key_usage': ['serverAuth', 'clientAuth'],
#     'authority_key_identifier': {'keyid': '5168ff90af0207753cccd9656462a212b859723b'},
#     'subject_alternative_name': ['*.hartfordhealthcare.org',
#      'hartfordhealthcare.org',
#      'hhchealth.org',
#      '*.hhchealth.org',
#      'hartfordhospital.org',
#      'thocc.org',
#      'Backushospital.org',
#      'midstatemedical.org',
#      'windhamhospital.org',
#      'charlottehungerford.org',
#      'stvincents.org',
#      'hhcseniorservices.org',
#      'hartfordhealthcareathome.org',
#      'integratedcarepartners.org',
#      'ctorthoinstitute.org',
#      'natchaug.org',
#      'rushford.org',
#      'hartfordhealthcarebhn.org',
#      'hhcbehavioralhealth.org',
#      'instituteofliving.org',
#      'hartfordhealthcaremedicalgroup.org',
#      'hartfordhealthcarerehabnetwork.org',
#      'healthnewshub.org',
#      'hhcconnect.org',
#      'www.hhcconnect.org',
#      'www.hartfordhospital.org',
#      'www.thocc.org',
#      'www.Backushospital.org',
#      'www.midstatemedical.org',
#      'www.windhamhospital.org',
#      'www.charlottehungerford.org',
#      'www.stvincents.org',
#      'www.hhcseniorservices.org',
#      'www.hartfordhealthcareathome.org',
#      'www.integratedcarepartners.org',
#      'www.ctorthoinstitute.org',
#      'www.natchaug.org',
#      'www.rushford.org',
#      'www.hartfordhealthcarebhn.org',
#      'www.hhcbehavioralhealth.org',
#      'www.instituteofliving.org',
#      'www.hartfordhealthcaremedicalgroup.org',
#      'www.hartfordhealthcarerehabnetwork.org',
#      'www.healthnewshub.org',
#      'prod.hartfordhealthcare.org',
#      'stage.hartfordhealthcare.org',
#      'dev.hartfordhealthcare.org',
#      '*.prod.hartfordhealthcare.org',
#      '*.stage.hartfordhealthcare.org',
#      '*.dev.hartfordhealthcare.org'],
#     'tags': [],
#     'subject_key_identifier': '432b3bc78d9706fea7c6082f62cc00d634e37a60',
#     'crl_distribution_points': ['http://crl3.digicert.com/sha2-ha-server-g6.crl',
#      'http://crl4.digicert.com/sha2-ha-server-g6.crl'],
#     'key_usage': ['ff'],
#     '1.3.6.1.4.1.11129.2.4.2': '0481f300f1007700b21e05cc8ba2cd8a204e8766f92bb98a2520676bdafa70e7',
#     'CA': True,
#     'ca_information_access': {'CA Issuers': 'http://cacerts.digicert.com/DigiCertSHA2HighAssuranceServerCA.crt',
#      'OCSP': 'http://ocsp.digicert.com'}},
#    'signature_algorithm': 'sha256RSA',
#    'thumbprint_sha256': 'b744a98e7237bbfa339932774da4a8c61978f4b0b2160eb1bc5fea1af969d6b2',
#    'thumbprint': 'a000bffbf62e35883825a01a1d1c912672059519',
#    'size': 2906,
#    'subject': {'C': 'US',
#     'CN': '*.hartfordhealthcare.org',
#     'L': 'Hartford',
#     'O': 'Hartford Healthcare Corporation',
#     'ST': 'CT',
#     'OU': 'Information Technology'}},
#   'type': 'ssl_cert',
#   'id': 'b744a98e7237bbfa339932774da4a8c61978f4b0b2160eb1bc5fea1af969d6b2',
#   'links': {'self': 'https://www.virustotal.com/api/v3/ssl_certs/b744a98e7237bbfa339932774da4a8c61978f4b0b2160eb1bc5fea1af969d6b2'},
#   'context_attributes': {'first_seen_date': '2020-05-23', 'port': '443'}}]

# %%
data_cas[0]["attributes"]["issuer"]["O"]
# Out:
# 'DigiCert Inc'

# %%
data_cas_2 = client.get_data("/domains/dbankcloud.asia/historical_ssl_certificates")

# %%
data_cas_2
# Out:
# []

# %% [markdown]
# # Virus Total API Filtering

# %%
df_not_selfsigned.reset_index(inplace=True, drop=True)
df_not_selfsigned
# Out:
#                            domain  \
# 0       sfd.et1240.epichosted.com
# 1       sfd.et1146.epichosted.com
# 2                ceprd.sjhsyr.org
# 3                sfprod.acpny.com
# 4                   ce.chppoc.org
# ..                            ...
# 104   carequality.crisphealth.org
# 105         US.info.lgsmartad.com
# 106           bmecmg.cloudapp.net
# 107  cehcahealthcare.stdavids.com
# 108        devops.shottracker.com
#
#                                               issuer_O  count
# 0                                           EMR Direct      1
# 1                                           EMR Direct      1
# 2                                           EMR Direct      2
# 3                                           EMR Direct      1
# 4                                           EMR Direct      1
# ..                                                 ...    ...
# 104                                         EMR Direct      1
# 105                                LG Electronics Inc.      1
# 106        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 107                                         EMR Direct      2
# 108  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
#
# [109 rows x 3 columns]

# %%
import time
import vt
def get_historical_ca(df: pd.DataFrame, client: vt.Client):
    historical_df = df.copy()
    historical_df.reset_index(drop=True, inplace=True)
    historical_cas = []
    for index, row in historical_df.iterrows():
        try:
            domain = row["domain"]
            ssl_ca_data = client.get_data(f"/domains/{domain}/historical_ssl_certificates")
            if len(ssl_ca_data) > 0:
                historical_cas.append(ssl_ca_data[0]["attributes"]["issuer"]["O"])
            else:
                historical_cas.append("None")
        except:
            historical_cas.append("Unable to find")
    historical_df["historical_ca"] = historical_cas
    return historical_df

# %%
import nest_asyncio
nest_asyncio.apply()
historical_df = get_historical_ca(df_not_selfsigned, client)
historical_df
# Out:
#                            domain  \
# 0       sfd.et1240.epichosted.com
# 1       sfd.et1146.epichosted.com
# 2                ceprd.sjhsyr.org
# 3                sfprod.acpny.com
# 4                   ce.chppoc.org
# ..                            ...
# 104   carequality.crisphealth.org
# 105         US.info.lgsmartad.com
# 106           bmecmg.cloudapp.net
# 107  cehcahealthcare.stdavids.com
# 108        devops.shottracker.com
#
#                                               issuer_O  count  \
# 0                                           EMR Direct      1
# 1                                           EMR Direct      1
# 2                                           EMR Direct      2
# 3                                           EMR Direct      1
# 4                                           EMR Direct      1
# ..                                                 ...    ...
# 104                                         EMR Direct      1
# 105                                LG Electronics Inc.      1
# 106        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 107                                         EMR Direct      2
# 108  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
#
#                 historical_ca
# 0                DigiCert Inc
# 1                DigiCert Inc
# 2                        None
# 3                        None
# 4                DigiCert Inc
# ..                        ...
# 104                      None
# 105                      None
# 106                      None
# 107  Trustwave Holdings, Inc.
# 108              DigiCert Inc
#
# [109 rows x 4 columns]

# %%
historical_df
# Out:
#                            domain  \
# 0       sfd.et1240.epichosted.com
# 1       sfd.et1146.epichosted.com
# 2                ceprd.sjhsyr.org
# 3                sfprod.acpny.com
# 4                   ce.chppoc.org
# ..                            ...
# 104   carequality.crisphealth.org
# 105         US.info.lgsmartad.com
# 106           bmecmg.cloudapp.net
# 107  cehcahealthcare.stdavids.com
# 108        devops.shottracker.com
#
#                                               issuer_O  count  \
# 0                                           EMR Direct      1
# 1                                           EMR Direct      1
# 2                                           EMR Direct      2
# 3                                           EMR Direct      1
# 4                                           EMR Direct      1
# ..                                                 ...    ...
# 104                                         EMR Direct      1
# 105                                LG Electronics Inc.      1
# 106        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 107                                         EMR Direct      2
# 108  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
#
#                 historical_ca
# 0                DigiCert Inc
# 1                DigiCert Inc
# 2                        None
# 3                        None
# 4                DigiCert Inc
# ..                        ...
# 104                      None
# 105                      None
# 106                      None
# 107  Trustwave Holdings, Inc.
# 108              DigiCert Inc
#
# [109 rows x 4 columns]

# %%
def save_historical_df(df: pd.DataFrame, source_file: str):
    file_ext_index = source_file.rfind(".")
    src_file_name = source_file[:file_ext_index]
    parquet_file_name = f"{src_file_name}_pos_intercept.parquet"
    df.to_parquet(parquet_file_name)
    return parquet_file_name

save_historical_df(historical_df, "2021-12-28.parquet")
# Out:
# '2021-12-28_pos_intercept.parquet'

# %%
test_df = pd.read_parquet("2021-12-28_pos_intercept.parquet")
test_df
# Out:
#                            domain  \
# 0       sfd.et1240.epichosted.com
# 1       sfd.et1146.epichosted.com
# 2                ceprd.sjhsyr.org
# 3                sfprod.acpny.com
# 4                   ce.chppoc.org
# ..                            ...
# 104   carequality.crisphealth.org
# 105         US.info.lgsmartad.com
# 106           bmecmg.cloudapp.net
# 107  cehcahealthcare.stdavids.com
# 108        devops.shottracker.com
#
#                                               issuer_O  count  \
# 0                                           EMR Direct      1
# 1                                           EMR Direct      1
# 2                                           EMR Direct      2
# 3                                           EMR Direct      1
# 4                                           EMR Direct      1
# ..                                                 ...    ...
# 104                                         EMR Direct      1
# 105                                LG Electronics Inc.      1
# 106        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co     15
# 107                                         EMR Direct      2
# 108  N=3x1M07 5EbvZ8tQOb 1V 4S1O61pWj 1w afGABq.48F...      1
#
#                 historical_ca
# 0                DigiCert Inc
# 1                DigiCert Inc
# 2                        None
# 3                        None
# 4                DigiCert Inc
# ..                        ...
# 104                      None
# 105                      None
# 106                      None
# 107  Trustwave Holdings, Inc.
# 108              DigiCert Inc
#
# [109 rows x 4 columns]
