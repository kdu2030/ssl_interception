# %%
from analysis_helpers.intercept_helpers import process_parquet_dir
import pandas as pd

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-05-31/"
df = process_parquet_dir(data_path)
# Out:
# /home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/analysis_helpers/intercept_helpers.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["does_ca_match"] = df.apply(lambda row: does_ca_match(row["issuer_O"], row["historical_ca"]), axis=1)

# %%
df
# Out:
#      index                                        domain  \
# 0        2                                  www.ofij.com
# 2       44                               qpush.qunar.com
# 4       87                            ncaiss-ps3.dss.mil
# 8      137                                na.b.g-tun.com
# 14     207                     settings-ssl.xboxlive.com
# 16       1        v-mcafeesqlp.customer.persistent.co.in
# 27     141                         outsunnyimg.aosom.com
# 30     187                         dcpsepohandler.dc.gov
# 38       8                        chat.accounts.sparx.io
# 56      49                tracking.culturalinsurance.com
# 65     139                      expressway.vatelemed.net
# 66     166                             business.bing.com
# 70     215                             fp-afd.azurefd.us
# 75     270                       rum18.perf.linkedin.com
# 76     301                              maps.windows.com
# ...

# %%
df[df["issuer_O"] == "Kabam Games Inc."]
# Out:
#     index                  domain          issuer_O  conn_count  \
# 38      8  chat.accounts.sparx.io  Kabam Games Inc.           1
#
#             historical_ca
# 38  Google Trust Services

# %%
df[df["issuer_O"] == "United Parcel Service"]
# Out:
#      index                       domain               issuer_O  conn_count  \
# 14     207    settings-ssl.xboxlive.com  United Parcel Service           1
# 66     166            business.bing.com  United Parcel Service           1
# 70     215            fp-afd.azurefd.us  United Parcel Service           1
# 75     270      rum18.perf.linkedin.com  United Parcel Service           1
# 76     301             maps.windows.com  United Parcel Service           1
# 154     25          fp-afd.azureedge.us  United Parcel Service           1
# 161     70    settings-ssl.xboxlive.com  United Parcel Service           1
# 162     72  fp-as-nocache.azureedge.net  United Parcel Service           1
#
#                                  historical_ca
# 14                       Microsoft Corporation
# 66                       Microsoft Corporation
# 70                                DigiCert Inc
# 75                                DigiCert Inc
# 76   {'Microsoft Corporation', 'DigiCert Inc'}
# ...

# %%
df[df["issuer_O"] == "Symantec Corporation"]
# Out:
#     index                          domain              issuer_O  conn_count  \
# 56     49  tracking.culturalinsurance.com  Symantec Corporation           4
#
#                           historical_ca
# 56  {'DigiCert Inc', 'Sectigo Limited'}
