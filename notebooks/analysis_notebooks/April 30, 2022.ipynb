# %% [markdown]
# # April 30, 2022

# %%
from analysis_helpers.intercept_helpers import process_parquet_dir
import pandas as pd

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-04-30/"
df = process_parquet_dir(data_path)
# Out:
# /home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/analysis_helpers/intercept_helpers.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["does_ca_match"] = df.apply(lambda row: does_ca_match(row["issuer_O"], row["historical_ca"]), axis=1)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df
# Out:
#      index  \
# 1        2
# 2        5
# 3        6
# 4       10
# 6       12
# 8        0
# 9        2
# 10       4
# 11       6
# 12      10
# 13      11
# 14      12
# 15      14
# 16      15
# 17      16
# 18      17
# 19      18
# 20      20
# 21      23
# 23      26
# 24      28
# 25      29
# 26      30
# 27      31
# 28      33
# 30      35
# 31      36
# 32      37
# 33      38
# 34      39
# 35      40
# 36      41
# 37      42
# 38      45
# 39      47
# 40      48
# 42      50
# 43      51
# 45      54
# 46      56
# 47      57
# 48      59
# 49      61
# 50      63
# 51      64
# 52      66
# 53      67
# 54      68
# 55      69
# 56      72
# 58      74
# 59      75
# 60      76
# 61      77
# 62      78
# 63      79
# 64      81
# 65      82
# 66      83
# 67      84
# 68      85
# 69      86
# 70      87
# 71      88
# 73      92
# 74      93
# 75      94
# 77      96
# 78      97
# 80      99
# 81     100
# 82     101
# 83     102
# 84     104
# 85     105
# ...

# %%
not_cisc = df[df["issuer_O"] != "Cisc"]
not_cisc.reset_index(inplace=True)
not_cisc.drop(["level_0", "index"], axis=1, inplace=True)
# Out:
# /home/ubuntu/local_pip/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
pd.options.display.max_colwidth = None
not_cisc
# Out:
#                                      domain  \
# 0                             b.kolavpn.win
# 1            global-turbo2-1.opera-mini.net
# 2              global-turbo2.opera-mini.net
# 3            global-turbo2-7.opera-mini.net
# 4                          sd.stockfuse.com
# 5                       grs.dbankcloud.asia
# 6   storage.accesscontrol.pandasecurity.com
# 7                              www.fthp.com
# 8                   US.ibsstat.lgappstv.com
# 9                       US.ad.lgsmartad.com
# 10                    US.info.lgsmartad.com
# 11                  collector.appoptics.com
# 12                  discovery.syncthing.net
# 13               discovery-v4.syncthing.net
# 14                     o7oo35.bytedance.com
# 15                         api.sessionm.com
# 16                           wiktionary.org
# 17                             testmart.com
# 18                           US.lgtvsdp.com
# 19                 expressway.vatelemed.net
# ...

# %%
df[df["issuer_O"] == "Acme C"]
# Out:
#      index            domain issuer_O  conn_count  \
# 86     106  sd.stockfuse.com   Acme C          14
# 198      8  api.sessionm.com   Acme C           1
#
#                                                                                               historical_ca
# 86   {'COMODO CA Limited', 'StartCom Ltd.', 'GlobalSign nv-sa', '"CloudFlare, Inc."', '"Cloudflare, Inc."'}
# 198            {'COMODO CA Limited', '"Starfield Technologies, Inc."', 'GeoTrust Inc.', '"GeoTrust, Inc."'}

# %%
df[df["issuer_O"] == "CloudFlare"]
# Out:
#      index                   domain    issuer_O  conn_count  \
# 272      1  www.savethehighseas.org  CloudFlare           1
#
#            historical_ca
# 272  "GoDaddy.com, Inc."
