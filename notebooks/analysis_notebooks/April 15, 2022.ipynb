# %%
from analysis_helpers.intercept_helpers import process_parquet_dir
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-04-15/"
df = process_parquet_dir(data_path)
# Out:
# /home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/analysis_helpers/intercept_helpers.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["does_ca_match"] = df.apply(lambda row: does_ca_match(row["issuer_O"], row["historical_ca"]), axis=1)

# %%
df
# Out:
#       index                         domain                      issuer_O  \
# 72      420       token.safebrowsing.apple                          Cisc
# 87       71             ols.chaosgroup.com               N=7Fw6H 2cMYVTs
# 93      134          ingress1.virgosvs.com  Virgo Surgical Video Systems
# 112     341  spring18.gosredirector.ea.com               Electronic Arts
# 115     382             gameplay.intel.com                          Cisc
# ...     ...                            ...                           ...
# 1429    445            grs.dbankcloud.asia                        Huawei
# 1430    451        coeafdcp.usace.army.mil               U.S. Government
# 1437    528              grs.dbankcloud.cn                        Huawei
# 1442    538            us.ad.lgsmartad.com           LG Electronics Inc.
# 1485    572              grs.dbankcloud.cn                        Huawei
#
#       conn_count                                      historical_ca
# ...

# %%
df.iloc[:28]
# Out:
#     index  \
# 5      61
# 9     122
# 11    151
# 13    218
# 16    233
# 20    268
# 23    299
# 24    311
# 25    320
# 28    366
# 29    369
# 31    463
# 36     87
# 38     94
# 45    146
# 48    186
# 50    192
# 53    230
# 57    283
# 62    359
# 64    368
# 65    377
# 66    382
# 69    411
# 70    418
# 74    464
# 76    469
# 80    533
#
#                                                                                domain  \
# 5                                                                  ols.chaosgroup.com
# 9                                                                      US.lgtvsdp.com
# 11                                                           expressway.vatelemed.net
# 13                                                         prd.samsungglobalgoals.com
# 16                                                            discovery.syncthing.net
# 20                                                        e2-cs2.support-download.com
# ...

# %%
not_cisc_df = df[df["issuer_O"] != "Cisc"]

# %%
df[df["issuer_O"] == "TAIWAN-CA"]
# Out:
#      index               domain   issuer_O  conn_count  \
# 452    163  topic.cheers.com.tw  TAIWAN-CA           2
#
#                           historical_ca
# 452  {'StartCom Ltd.', "Let's Encrypt"}

# %%
not_cisc_df.iloc[0:35]
# Out:
#      index                                          domain  \
# 5       61                              ols.chaosgroup.com
# 9      122                                  US.lgtvsdp.com
# 11     151                        expressway.vatelemed.net
# 13     218                      prd.samsungglobalgoals.com
# 16     233                         discovery.syncthing.net
# 20     268                     e2-cs2.support-download.com
# 23     299                           ingress2.virgosvs.com
# 24     311                           4m1g2IRz.virginia.edu
# 25     320                                avcloud02.bd.com
# 28     366                      discovery-v4.syncthing.net
# 31     463                               grs.dbankcloud.cn
# 38      94                              ols.chaosgroup.com
# 45     146                         collector.appoptics.com
# 48     186                            ag-gateway-03.cmc.ca
# 50     192                                  US.lgtvsdp.com
# ...

# %%
not_cisc_df
# Out:
#      index                      domain  \
# 5       61          ols.chaosgroup.com
# 9      122              US.lgtvsdp.com
# 11     151    expressway.vatelemed.net
# 13     218  prd.samsungglobalgoals.com
# 16     233     discovery.syncthing.net
# ..     ...                         ...
# 535    434       43iYCyMl.virginia.edu
# 537    445         grs.dbankcloud.asia
# 538    451     coeafdcp.usace.army.mil
# 545    528           grs.dbankcloud.cn
# 550    538         us.ad.lgsmartad.com
#
#                                              issuer_O  conn_count  \
# 5                                     N=7Fw6H 2cMYVTs           2
# 9                                 LG Electronics Inc.           2
# 11   Temporary CA a0305fb9-1d21-4142-9f97-e1c6efdab8f           9
# 13                                 Samsung Opus group           1
# 16                                         N=4K2VsoWa          16
# ..                                                ...         ...
# ...

# %%
df[df["issuer_O"] == "Bristol-Myers Squib"]
# Out:
#      index                  domain             issuer_O  conn_count  \
# 151    142  hp1cmg.one.ads.bms.com  Bristol-Myers Squib          26
#
#     historical_ca
# 151  DigiCert Inc

# %%
pd.set_option('display.max_colwidth', None)
df[df["issuer_O"] == "VK"]
# Out:
#      index                  domain issuer_O  conn_count  \
# 208    295  news.radar.imgsmail.ru       VK           4
#
#                                                                historical_ca
# 208  {'GeoTrust Inc.', '"Thawte, Inc."', 'DigiCert Inc', 'GlobalSign nv-sa'}

# %%
print(df[df["issuer_O"] == "VK"]["historical_ca"])
# Out:
# 208    {'GeoTrust Inc.', '"Thawte, Inc."', 'DigiCert Inc', 'GlobalSign nv-sa'}
# Name: historical_ca, dtype: object

# %%
not_cisc_df[35:]
# Out:
#      index                                   domain  \
# 175    206            winter15.gosredirector.ea.com
# 177    214                    ingress1.virgosvs.com
# 192    249                     ag-gateway-03.cmc.ca
# 197    261                           US.lgtvsdp.com
# 208    295                   news.radar.imgsmail.ru
# 212    308                 expressway.vatelemed.net
# 228    376                  puppetserver.airbnb.biz
# 255    449                  dgcomm-prod07.gedlp.com
# 266    474                         push.hicloud.com
# 267    476                  discovery.syncthing.net
# 289    546            spring18.gosredirector.ea.com
# 301    584               grs.platform.dbankcloud.ru
# 302    588            carsk4nfncagh04.actd.army.mil
# 312    611                    ingress2.virgosvs.com
# 347    700                     ag-gateway-04.cmc.ca
# 368    765               discovery-v4.syncthing.net
# 376    781                             gosca.ea.com
# ...

# %% [markdown]
# # Issuers that are not CISC

# %%
not_cisc_df
# Out:
#       index                         domain                      issuer_O  \
# 87       71             ols.chaosgroup.com               N=7Fw6H 2cMYVTs
# 93      134          ingress1.virgosvs.com  Virgo Surgical Video Systems
# 112     341  spring18.gosredirector.ea.com               Electronic Arts
# 119     411               avcloud02.bd.com                        Becton
# 138      61             ols.chaosgroup.com               N=7Fw6H 2cMYVTs
# ...     ...                            ...                           ...
# 1429    445            grs.dbankcloud.asia                        Huawei
# 1430    451        coeafdcp.usace.army.mil               U.S. Government
# 1437    528              grs.dbankcloud.cn                        Huawei
# 1442    538            us.ad.lgsmartad.com           LG Electronics Inc.
# 1485    572              grs.dbankcloud.cn                        Huawei
#
#       conn_count                                      historical_ca
# ...

# %%
not_cisc_df.iloc[100:136]
# Out:
#       index                                   domain  \
# 970     157                           US.lgtvsdp.com
# 972     163                      topic.cheers.com.tw
# 974     190                 expressway.vatelemed.net
# 977     257               maps-prd.go.tesla.services
# 980     296                         push.hicloud.com
# 981     297                  discovery.syncthing.net
# 982     330                      US.ibs.lgappstv.com
# 983     332            spring18.gosredirector.ea.com
# 988     409          telemetry-prd.ap.tesla.services
# 991     461               discovery-v4.syncthing.net
# 992     479  00199D0336-drmp.support.supportview.com
# 993     493                    43iYCyMl.virginia.edu
# 994     506                      grs.dbankcloud.asia
# 999     599                        grs.dbankcloud.cn
# 1010     96                           wikisource.org
# 1029    348                           wiktionary.org
# 1084    341                  discovery.syncthing.net
# ...

# %%
not_cisc_df.iloc[64:100]
# Out:
#      index                                   domain  \
# 582    162                 expressway.vatelemed.net
# 584    194                    1lLa8qWn.virginia.edu
# 588    267                         push.hicloud.com
# 589    269                  discovery.syncthing.net
# 590    276                      US.ad.lgsmartad.com
# 591    299                      US.ibs.lgappstv.com
# 592    301            spring18.gosredirector.ea.com
# 596    336                    ingress2.virgosvs.com
# 598    359                         avcloud02.bd.com
# 599    367    00199D0305-da.support.supportview.com
# 602    410               discovery-v4.syncthing.net
# 605    424                             gosca.ea.com
# 606    429                     o7oo35.bytedance.com
# 611    527                        grs.dbankcloud.cn
# 612    529                    US.info.lgsmartad.com
# 613    537                      us.ad.lgsmartad.com
# 660    226                   news.radar.imgsmail.ru
# ...
