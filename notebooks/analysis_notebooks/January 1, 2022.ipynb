# %% [markdown]
# # January 1, 2022 Data

# %%
from analysis_helpers.intercept_helpers import process_parquet_dir
import pandas as pd

# %% [markdown]
# **Loading Parquets**

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-01-01/"
df = process_parquet_dir(data_path)
# Out:
# /home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/analysis_helpers/intercept_helpers.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["does_ca_match"] = df.apply(lambda row: does_ca_match(row["issuer_O"], row["historical_ca"]), axis=1)

# %%
df = df[(df["issuer_O"] != "LG Electronics Inc.") & (df["issuer_O"] != "Huawei") & (df["issuer_O"] != "Cisc") & (df["issuer_O"] != "Cisc")]
df
# Out:
#      index                                          domain  \
# 2       38                              ols.chaosgroup.com
# 13     131                                        nrao.edu
# 15     158  device.device-management.prod.k8s.pelotime.com
# 16     162                         discovery.syncthing.net
# 20     206                           ingress2.virgosvs.com
# ..     ...                                             ...
# 466    167  device.device-management.prod.k8s.pelotime.com
# 467    171                         discovery.syncthing.net
# 470    234                 telemetry-prd.ap.tesla.services
# 471    259                         update.blinemedical.com
# 472    269                      discovery-v4.syncthing.net
#
#                           issuer_O  conn_count  \
# 2                  N=7Fw6H 2cMYVTs           1
# 13                 Polycom DMA 700           4
# 15         Peloton Interactive Inc           4
# 16                      N=4K2VsoWa           8
# ...

# %% [markdown]
# **Filtering out N= in issuer_O**

# %%
df = df[~df["issuer_O"].astype(str).str.startswith("N=")]
df
# Out:
#      index                                          domain  \
# 13     131                                        nrao.edu
# 15     158  device.device-management.prod.k8s.pelotime.com
# 20     206                           ingress2.virgosvs.com
# 34     132                                        nrao.edu
# 37     159                           video-meetme.nrao.edu
# 44     228           00199D0305-da.support.supportview.com
# 46     283                             bit9.aramarkpos.net
# 55      73                           269UhP0O.virginia.edu
# 56      78                           ingress1.virgosvs.com
# 58      98                                 cdn2.signal.org
# 64     154                                        nrao.edu
# 66     164                                 5TWYUuT3.vt.edu
# 68     182  device.device-management.prod.k8s.pelotime.com
# 87      71                         collector.appoptics.com
# 94     151                                        nrao.edu
# ...

# %%
df[df["issuer_O"] == "Open Whisper Systems"]
# Out:
#     index           domain              issuer_O  conn_count  \
# 58     98  cdn2.signal.org  Open Whisper Systems           4
#
#                                         historical_ca
# 58  {'"CloudFlare, Inc."', '"Cloudflare, Inc."', '...

# %%
df[df["issuer_O"] == "Open Whisper Systems"]
# Out:
#     index           domain              issuer_O  conn_count  \
# 58     98  cdn2.signal.org  Open Whisper Systems           4
#
#                                         historical_ca
# 58  {'"CloudFlare, Inc."', '"Cloudflare, Inc."', '...
