# %%
from analysis_helpers.intercept_helpers import process_parquet_dir
import pandas as pd

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-05-15/"
df = process_parquet_dir(data_path)
# Out:
# /home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/analysis_helpers/intercept_helpers.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["does_ca_match"] = df.apply(lambda row: does_ca_match(row["issuer_O"], row["historical_ca"]), axis=1)

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#    index                                          domain  \
# 2      5                                     api.msn.com
# 6     29                              ols.chaosgroup.com
# 10    60                        expressway.vatelemed.net
# 14    91                         discovery.syncthing.net
# 30     0                                fd.qchannel03.cn
# 31     3                               log.qchannel03.cn
# 32     4                                 d.qchannel03.cn
# 35    14  device.device-management.prod.k8s.pelotime.com
# 48    82                        expressway.vatelemed.net
# 51   129                         discovery.syncthing.net
# 58   193                      discovery-v4.syncthing.net
# 62   245                               grs.dbankcloud.cn
# 73     6                                     api.msn.com
# 74     8                                   b.kolavpn.win
# 75    11                                    www.bing.com
# ...

# %%
pd.set_option('display.max_colwidth', None)
df[df["issuer_O"] == "GeoTrust Inc."]
# Out:
#    index             domain       issuer_O  conn_count  \
# 30     0   fd.qchannel03.cn  GeoTrust Inc.           2
# 31     3  log.qchannel03.cn  GeoTrust Inc.           2
# 32     4    d.qchannel03.cn  GeoTrust Inc.           2
#
#                                          historical_ca
# 30  {'"TrustAsia Technologies, Inc."', 'DigiCert Inc'}
# 31  {'"TrustAsia Technologies, Inc."', 'DigiCert Inc'}
# 32  {'"TrustAsia Technologies, Inc."', 'DigiCert Inc'}

# %%
df[df["issuer_O"] == "Intuitive"]
# Out:
#    index        domain   issuer_O  conn_count          historical_ca
# 2      5   api.msn.com  Intuitive           1  Microsoft Corporation
# 73     6   api.msn.com  Intuitive           1  Microsoft Corporation
# 75    11  www.bing.com  Intuitive           1  Microsoft Corporation
