# %%
from analysis_helpers.intercept_helpers import process_parquet_dir
import pandas as pd

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-06-01_2022-06-30/"
df = process_parquet_dir(data_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/June 2022.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2B192.168.0.37/home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/June%202022.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-07-01_2022-07-31/"
# ----> <a href='vscode-notebook-cell://ssh-remote%2B192.168.0.37/home/ubuntu/GitLab/ssl_interception/notebooks/analysis_notebooks/June%202022.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> df = process_parquet_dir(data_path)
#
# NameError: name 'process_parquet_dir' is not defined

# %%
pd.set_option("max_row", None)
df
# Out:
#      index                                             domain  \
# 11      39                                     alt-ad.mail.ru
# 14      86                    dtsproweb.defensetravel.osd.mil
# 27      14                    apitrusted.paloaltonetworks.com
# 39       3                                  www.pathpedia.com
# 47      45                         federation.prod.cce.af.mil
# 49      56                     tracking.culturalinsurance.com
# 50      61                                      www.my.af.mil
# 56      12                          mhcewiz.identification.fr
# 58      17                                  www.gcss.army.mil
# 59      26                                     repo.febio.org
# 60      32                                     cloudfront.net
# 62      43                                      gcss.army.mil
# 70      72                               www.hrcapps.army.mil
# 73      15                                     na.b.g-tun.com
# ...

# %%
unique_issuers = df["issuer_O"].unique()
for issuer in unique_issuers:
    print(issuer)
# Out:
# VK
# U.S. Government
# Palo-Alto-Networks-Inc.
# N=2hsqsq-2XqsqkB
# Symantec Corporation
# ASK
# Let's Encrypt
# Project Fi - Session Continuity Tea
# N=www.gpm7ns3wbzmqbxdkbnt5.co
# N=7Fw6H 2cMYVTs
# Internet2
# CloudFlare
# N=uGPnM2n4wJj 5EbvZ8tQOb 1V,DC=healthsouth,DC=insidehrc,DC=co
# T. Rowe Price Associates Inc
# N=7mB4f7XE3U-1V,DC=aamc,DC=or
# Opera Software ASA
# N=7L1eRVfVD9k,DC=ethyl,DC=ne
# N=1p8LL1UI-3dCp-3JNI-1h1C-6jxWYAkVWFC
# N=67FxPju
# Huawei
# N=6vZsKwq6-o4UY-71NB-3zt5-3lcIZOjxSpF
# GeoTrust Inc.
# N=3x1M07 1V: 7dAoqV43.6TvBx0Nq6.6l
# LBE
# Samsung Opus group
# N=DgeCL AodfQR 7Os 5jYylAHA 1
# GlobalSign nv-sa
# N=6-3jNv2D 6vX 5EbvZ8tQOb 5lja1WF 1V 1m,DC=gsm1900,DC=or
# N=5a8uEGx 73oFVybUf 5lja1WF 1V
# BAYE
# GoGetSSL
# COMODO CA Limited
# Northrop Grumman Corporation
# N=5jANS_HoC46Ta_5NwR_7e4ao
# (STAGING) Let's Encrypt
# N=2h0oNw
# Temporary CA a0305fb9-1d21-4142-9f97-e1c6efdab8f
# N=4K2VsoWa
# McAfee Inc.
# Dehuinet
# FNMT-RCM
# Kabam Games Inc.
# ...

# %% [markdown]
# **Palo-Alto-Networks-Inc.**

# %% [markdown]
# Likely self-signed

# %%
pd.set_option("max_colwidth", None)
df[df["issuer_O"] == "Palo-Alto-Networks-Inc."]
# Out:
#      index                           domain                 issuer_O  \
# 27      14  apitrusted.paloaltonetworks.com  Palo-Alto-Networks-Inc.
# 1308    11  apitrusted.paloaltonetworks.com  Palo-Alto-Networks-Inc.
#
#       conn_count  \
# 27             1
# 1308           1
#
#                                                                                                                                                                                                                                                                                                                                                                                    historical_ca
# ...

# %% [markdown]
# **ASK**

# %% [markdown]
# * Only domain affected - mhcewiz.identification.fr
# * WHOIS information: https://whois.domaintools.com/identification.fr
# * Paragon Identification - Smart Card Company
# * ASK was Paragon Identification's old name - Likely self-signed certificate

# %%
df[df["issuer_O"] == "ASK"]
# Out:
#      index                     domain issuer_O  conn_count  \
# 56      12  mhcewiz.identification.fr      ASK           5
# 301      0  mhcewiz.identification.fr      ASK           5
# 1087     5  mhcewiz.identification.fr      ASK           5
# 1289     0  mhcewiz.identification.fr      ASK           6
# 1820    67  mhcewiz.identification.fr      ASK           5
#
#                                                                                                                  historical_ca
# 56    ['Gandi (2022-05-09 - 2023-05-09)', 'DigiCert Inc (2018-05-22 - 2019-08-21)', 'GeoTrust Inc. (2016-06-08 - 2017-06-08)']
# 301   ['Gandi (2022-05-09 - 2023-05-09)', 'DigiCert Inc (2018-05-22 - 2019-08-21)', 'GeoTrust Inc. (2016-06-08 - 2017-06-08)']
# 1087  ['Gandi (2022-05-09 - 2023-05-09)', 'DigiCert Inc (2018-05-22 - 2019-08-21)', 'GeoTrust Inc. (2016-06-08 - 2017-06-08)']
# ...

# %% [markdown]
# **T. Rowe Price Associates Inc**

# %% [markdown]
# * https://www.troweprice.com/personal-investing/index.html?&PlacementGUID=p74621163142&AdType=search&gclsrc=aw.ds&gad=1&gclid=CjwKCAjwxr2iBhBJEiwAdXECw2YBgAjPIKD48tH9S0jXXOTB7dfCY59Yct0aOMNInAxWcD8yLfgTBhoC6H0QAvD_BwE
# * Investment Firm

# %%
df[df["issuer_O"] == "T. Rowe Price Associates Inc"]
# Out:
#      index                                             domain  \
# 139      3                    settings-win.data.microsoft.com
# 255     28                                       www.bing.com
# 260     86                        ent-shasta-rrs.symantec.com
# 329     29                                na84.salesforce.com
# 330     30                          settings-ssl.xboxlive.com
# 335    155                               app.salesforceiq.com
# 355     63                             iecvlist.microsoft.com
# 455     29                     smartscreen-prod.microsoft.com
# 713     56                        settings.data.microsoft.com
# 715     77                                 edge.microsoft.com
# 718    112                              goto-desktop.goto.com
# 729     50                             iecvlist.microsoft.com
# 927      9                        settings.data.microsoft.com
# 1274     4                                na84.salesforce.com
# ...

# %% [markdown]
# **LBE**

# %% [markdown]
# * Likely self-signed

# %%
df[df["issuer_O"] == "LBE"]
# Out:
#     index         domain issuer_O  conn_count  \
# 242     3  cc.lbesec.com      LBE           1
# 325     9  cc.lbesec.com      LBE           1
#
#                         historical_ca
# 242  Amazon (2021-11-01 - 2022-11-30)
# 325  Amazon (2021-11-01 - 2022-11-30)

# %% [markdown]
# **BAYE**

# %% [markdown]
# * Hard to find data on organization
# * BAYE Foundation - https://projects.propublica.org/nonprofits/organizations/396040573
# * Business Acceleration for Young Entrepreneurs in Africa? - https://www.linkedin.com/company/baye-africa/?originalSubdomain=ke

# %%
df[df["issuer_O"] == "BAYE"]
# Out:
#     index                         domain issuer_O  conn_count  \
# 362    12  qagpublic.qg2.apps.qualys.com     BAYE           2
# 363    21               maps.windows.com     BAYE           1
# 366    29     imgssl.constantcontact.com     BAYE           1
# 375    72      files.constantcontact.com     BAYE           1
# 693    11                    arc.msn.com     BAYE           2
# 705   102                 assets.msn.com     BAYE           4
# 706   107            redirector.gvt1.com     BAYE           1
# 709   113             edgedl.me.gvt1.com     BAYE           2
#
#                                                                                                                                                                         historical_ca
# 362                                                                                      ['DigiCert Inc (2022-02-16 - 2023-02-16)', 'Symantec Corporation (2017-01-27 - 2019-01-28)']
# ...

# %% [markdown]
# **Northrop Grumman Corporation**

# %% [markdown]
# * Northrop Grumman is a defense contractor - https://www.northropgrumman.com/

# %%
df[df["issuer_O"] == "Northrop Grumman Corporation"]
# Out:
#     index                         domain                      issuer_O  \
# 414     1  memcmgprd01.usgovcloudapp.net  Northrop Grumman Corporation
# 415     6  memcmgprd02.usgovcloudapp.net  Northrop Grumman Corporation
#
#      conn_count                                    historical_ca
# 414           1  Microsoft Corporation (2019-07-01 - 2021-07-01)
# 415           7  Microsoft Corporation (2019-07-01 - 2021-07-01)

# %% [markdown]
# **Dehuinet**

# %% [markdown]
# * msg.my9fi.com not logged in Censys.io's database
# * SSL Labs confirms that msg.my9fi.com uses a Sectigo Certificate
# * My9Fi seems like a scam - https://www.my9fi.com/#/home
# * https://github.com/dehuinet - Network company based in Beijing

# %%
df[df["issuer_O"] == "Dehuinet"]
# Out:
#      index         domain  issuer_O  conn_count  \
# 460     97  msg.my9fi.com  Dehuinet           1
# 1337    40  msg.my9fi.com  Dehuinet           1
# 1713   101  msg.my9fi.com  Dehuinet           1
# 2081    58  msg.my9fi.com  Dehuinet           1
#
#                                   historical_ca
# 460   Sectigo Limited (2022-02-11 - 2023-03-14)
# 1337  Sectigo Limited (2022-02-11 - 2023-03-14)
# 1713  Sectigo Limited (2022-02-11 - 2023-03-14)
# 2081  Sectigo Limited (2022-02-11 - 2023-03-14)

# %% [markdown]
# **FNMT-RCM**
# * Public certificate that wasn't parsed out

# %%
df[df["issuer_O"] == "FNMT-RCM"]
# Out:
#     index                domain  issuer_O  conn_count  \
# 463   129  alertcops.ses.mir.es  FNMT-RCM           1
#
#                                                                                                                 historical_ca
# 463  ['"Cloudflare, Inc." (2022-03-31 - 2023-03-30)', 'FNMT-RCM (2021-12-01 - 2022-12-01)', 'FNMT (2014-06-17 - 2016-06-17)']

# %% [markdown]
# **Zhixin New Information**
# * Issuer not logged in Crt.sh or Virus Total
# * Zhixin New Information is the issuer organization of grs.hihonorcloud.com as confirmed by Censys.io

# %%
df[df["issuer_O"] == "Zhixin New Information"]
# Out:
#     index                domain                issuer_O  conn_count  \
# 509     9  grs.hihonorcloud.com  Zhixin New Information           1
#
#                                   historical_ca
# 509  GlobalSign nv-sa (2023-01-17 - 2024-02-18)

# %% [markdown]
# **Network Solutions L.L.C.**

# %% [markdown]
# * Historical CA matches Issuer_O in SSL and X509 Logs - Wasn't parsed out

# %%
df[df["issuer_O"] == "Network Solutions L.L.C."]
# Out:
#     index               domain                  issuer_O  conn_count  \
# 728    49  www.gradleaders.com  Network Solutions L.L.C.           6
#
#                                           historical_ca
# 728  Network Solutions L.L.C. (2021-12-04 - 2022-12-07)

# %% [markdown]
# **Surescripts LLC.**

# %% [markdown]
# * Surescripts L.L.C. is a certificate issuer for cerpnp.vssjude.cloud as confirmed by Censys.io

# %%
df[df["issuer_O"] == "Surescripts LLC."]
# Out:
#     index                domain          issuer_O  conn_count  \
# 690    74  cerpnp.vssjude.cloud  Surescripts LLC.           1
# 922   305  cerpnp.vssjude.cloud  Surescripts LLC.           2
#
#                                      historical_ca
# 690  "GoDaddy.com, Inc." (2021-06-28 - 2022-07-30)
# 922  "GoDaddy.com, Inc." (2021-06-28 - 2022-07-30)

# %% [markdown]
# **Cardinal Healt**

# %% [markdown]
# * Likely self-signed certificate

# %%
df[df["issuer_O"] == "Cardinal Healt"]
# Out:
#      index                    domain        issuer_O  conn_count  \
# 711     10   ibcm.cardinalhealth.com  Cardinal Healt          10
# 1586     8   ibcm.cardinalhealth.com  Cardinal Healt          10
# 2160     4   ibcm.cardinalhealth.com  Cardinal Healt          20
# 2165    43  upds2.cardinalhealth.com  Cardinal Healt           3
# 2326    20  upds2.cardinalhealth.com  Cardinal Healt           2
#
#                                                                                                                                                                                                                                                                                                                                                                                                   historical_ca
# ...

# %% [markdown]
# **Positive Software**

# %% [markdown]
# * https://www.positive.software/
# * Provides medium to small size businesses with inventory management software

# %%
df[df["issuer_O"] == "Positive Software"]
# Out:
#      index                        domain           issuer_O  conn_count  \
# 800     66  ylobronc.users.superford.org  Positive Software           6
# 2314     9     www.blindmusicstudent.org  Positive Software           1
#
#                                  historical_ca
# 800    Let's Encrypt (2022-11-08 - 2023-02-06)
# 2314  "cPanel, Inc." (2023-01-19 - 2023-04-19)

# %% [markdown]
# **Synology Inc.**
# * https://www.synology.com/en-global
# * Provides data management and protection services, cloud services, and Network Attached Storage (NAS)

# %%
df[df["issuer_O"] == "Synology Inc."]
# Out:
#      index                 domain       issuer_O  conn_count  \
# 857     59  35FOtDkD.virginia.edu  Synology Inc.           7
# 1810     4        www.longvcd.com  Synology Inc.           1
#
#                                                                                                                                                historical_ca
# 857                                ['Internet2 (2022-06-10 - 2023-06-10)', 'DigiCert Inc (2007-06-05 - 2008-08-07)', 'ChainedSSL (2005-03-31 - 2007-07-01)']
# 1810  ['"TrustAsia Technologies, Inc." (2022-07-28 - 2023-07-28)', '"Cloudflare, Inc." (2022-07-23 - 2023-07-22)', 'DigiCert Inc (2021-08-11 - 2022-08-11)']

# %% [markdown]
# **Transurban Limited**
# * Toll Road company - https://www.transurban.com/north-america?adobe_mc_sdid=SDID%3D21D040D3745F9F75-3D6F0B8B11919864%7CMCORGID%3D7A0DBB1A56CC37127F000101%40AdobeOrg%7CTS%3D1683055694&adobe_mc_ref=https%3A%2F%2Fwww.google.com%2F

# %%
df[df["issuer_O"] == "Transurban Limited"]
# Out:
#      index                domain            issuer_O  conn_count  \
# 887      1           arc.msn.com  Transurban Limited           1
# 897     17      maps.windows.com  Transurban Limited           1
# 2312   245  cc-api-data.adobe.io  Transurban Limited           1
# 2313   272       notify.adobe.io  Transurban Limited           2
#
#                                                                                                                                    historical_ca
# 887                                                                                              Microsoft Corporation (2022-05-21 - 2023-05-16)
# 897                                                ['Microsoft Corporation (2021-11-10 - 2022-11-10)', 'DigiCert Inc (2021-07-10 - 2022-07-10)']
# 2312  ['DigiCert Inc (2022-05-30 - 2023-06-30)', 'Symantec Corporation (2014-10-15 - 2017-10-27)', '"VeriSign, Inc." (2013-10-28 - 2014-10-28)']
# ...

# %% [markdown]
# **CertCloud Pte. Ltd.**

# %%
df[df["issuer_O"] == "CertCloud Pte. Ltd."]
# Out:
#     index               domain             issuer_O  conn_count  \
# 913     8  notes.tarakanov.net  CertCloud Pte. Ltd.         105
#
#                                                                                                                                                                                                                                      historical_ca
# 913  ['GlobalSign nv-sa (2023-01-19 - 2024-02-20)', 'Sectigo Limited (2023-01-19 - 2023-04-19)', '"TrustAsia Technologies, Inc." (2022-10-19 - 2023-01-17)', 'CertCloud Pte. Ltd. (2022-04-20 - 2022-07-19)', 'ZeroSSL (2021-10-22 - 2022-01-20)']

# %% [markdown]
# **CMI**

# %% [markdown]
# * CMI issued a certificate for app3.jegotrip.com.cn, confirmed by SSL Certificate Checker

# %%
df[df["issuer_O"] == "CMI"]
# Out:
#     index                domain issuer_O  conn_count  \
# 914    96  app3.jegotrip.com.cn      CMI           1
#
#                               historical_ca
# 914  DigiCert Inc (2022-01-18 - 2023-02-08)

# %% [markdown]
# **Indus**

# %% [markdown]
# * Indus is confirmed as the certificate issuer by Censys.io

# %%
df[df["issuer_O"] == "Indus"]
# Out:
#      index                      domain issuer_O  conn_count  \
# 1119    28  discover-api.appbazaar.com    Indus           2
#
#                                                                                                                     historical_ca
# 1119  ['Amazon (2021-12-20 - 2023-01-17)', 'DigiCert Inc (2023-01-25 - 2024-01-25)', 'Sectigo Limited (2021-06-07 - 2022-06-07)']

# %% [markdown]
# **thawte**

# %% [markdown]
# * Thawte provides SSL Certificates - https://www.thawte.com/
# * Likely case of medwow.com switching Public Trust CAs

# %%
df[df["issuer_O"] == "thawte"]
# Out:
#      index          domain issuer_O  conn_count  \
# 1189    62  www.medwow.com   thawte           1
#
#                                          historical_ca
# 1189  VeriSign Trust Network (2008-05-04 - 2009-05-04)

# %% [markdown]
# **L3 Harris Technologies**
# * L3 Harris is an defense contractor
# * Probably a self signed certificate

# %%
df[df["issuer_O"] == "L3 Harris Technologies"]
# Out:
#      index                     domain                issuer_O  conn_count  \
# 1358    40  lhxcmg1.usgovcloudapp.net  L3 Harris Technologies          13
#
#                                         historical_ca
# 1358  Microsoft Corporation (2019-07-01 - 2021-07-01)

# %% [markdown]
# **SOG**

# %% [markdown]
# * SOG is the confirmed issuer of sccmibcm.gta.ga.gov by Censys.io
# * Likely a self-signed certificate
# * SOG - may stand for State of Georgia

# %%
df[df["issuer_O"] == "SOG"]
# Out:
#      index               domain issuer_O  conn_count  \
# 1383    40  sccmibcm.gta.ga.gov      SOG          55
# 1478    26  sccmibcm.gta.ga.gov      SOG          11
# 1664   177  sccmibcm.gta.ga.gov      SOG          37
# 2235    49  sccmibcm.gta.ga.gov      SOG          68
# 2328    33  sccmibcm.gta.ga.gov      SOG          57
#
#                                historical_ca
# 1383  DigiCert Inc (2022-03-09 - 2023-03-01)
# 1478  DigiCert Inc (2022-03-09 - 2023-03-01)
# 1664  DigiCert Inc (2022-03-09 - 2023-03-01)
# 2235  DigiCert Inc (2022-03-09 - 2023-03-01)
# 2328  DigiCert Inc (2022-03-09 - 2023-03-01)

# %% [markdown]
# **Starfield Technologies**

# %%
df[df["issuer_O"] == "Starfield Technologies"]
# Out:
#      index            domain                issuer_O  conn_count  \
# 1489    76  rts.contivio.net  Starfield Technologies           1
#
#                                                  historical_ca
# 1489  "Starfield Technologies, Inc." (2014-08-25 - 2017-06-06)

# %% [markdown]
# **MANDIANT**
# * Cybersecurity software firm - https://www.mandiant.com/advantage
# * Provides security monitoring software

# %%
df[df["issuer_O"] == "MANDIANT"]
# Out:
#      index                                                      domain  \
# 1597   122  sfServer.hexpfw547-hx-agent-1.hex01.helix.apps.fireeye.com
# 1598   125     sfPKI.hexpfw547-hx-agent-1.hex01.helix.apps.fireeye.com
#
#       issuer_O  conn_count  \
# 1597  MANDIANT           3
# 1598  MANDIANT           3
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         historical_ca
# ...

# %% [markdown]
# **Linden Lab**

# %% [markdown]
# * Linden Lab is the company that created Second Life
# * Self-signed certificate

# %%
df[df["issuer_O"] == "Linden Lab"]
# Out:
#      index                                        domain    issuer_O  \
# 1692    17  simhost-055583d1568907ecd.agni.secondlife.io  Linden Lab
# 2211    28  simhost-0bc9b431311e027a6.agni.secondlife.io  Linden Lab
#
#       conn_count  \
# 1692           8
# 2211          48
#
#                                                                        historical_ca
# 1692  ['Amazon (2021-09-14 - 2022-10-13)', 'DigiCert Inc (2016-09-27 - 2019-10-02)']
# 2211  ['Amazon (2021-09-14 - 2022-10-13)', 'DigiCert Inc (2016-09-27 - 2019-10-02)']

# %% [markdown]
# **XM**

# %% [markdown]
# * haxm.co likely used a self-signed or private certificate that later switched to a public issuer

# %%
df[df["issuer_O"] == "XM"]
# Out:
#      index               domain issuer_O  conn_count  \
# 1787     3  s-karlstorz.haxm.co       XM           1
#
#                                                                                            historical_ca
# 1787  ["Let's Encrypt (2023-04-23 - 2023-07-22)", 'Google Trust Services LLC (2023-04-23 - 2023-07-22)']

# %% [markdown]
# **LifeSize Communications**
# * Video Conferencing company - https://www.lifesize.com/cxengage-by-serenova/

# %%
df[df["issuer_O"] == "LifeSize Communications"]
# Out:
#      index      domain                 issuer_O  conn_count  \
# 1815    36  www.kan.cc  LifeSize Communications           1
#
#                                                                                                                                           historical_ca
# 1815  ["Let's Encrypt (2023-02-28 - 2023-05-29)", '"TrustAsia Technologies, Inc." (2021-11-26 - 2022-11-25)', 'DigiCert Inc (2021-09-01 - 2022-09-01)']

# %% [markdown]
# **Schneider Electric**

# %% [markdown]
# * Energy company based in France - https://www.se.com/us/en/

# %%
df[df["issuer_O"] == "Schneider Electric"]
# Out:
#      index      domain            issuer_O  conn_count  \
# 1838   195  www.kan.cc  Schneider Electric           1
#
#                                                                                                                                           historical_ca
# 1838  ["Let's Encrypt (2023-02-28 - 2023-05-29)", '"TrustAsia Technologies, Inc." (2021-11-26 - 2022-11-25)', 'DigiCert Inc (2021-09-01 - 2022-09-01)']

# %% [markdown]
# **KARL STORZ SE & Co. KG**

# %% [markdown]
# * Karl Storz is a German medicine company - https://www.karlstorz.com/

# %%
df[df["issuer_O"] == "KARL STORZ SE & Co. KG"]
# Out:
#      index                                domain                issuer_O  \
# 1922     7             ims-prod06.adobelogin.com  KARL STORZ SE & Co. KG
# 1948     6                           arc.msn.com  KARL STORZ SE & Co. KG
# 2365    12                    client-log.box.com  KARL STORZ SE & Co. KG
# 2366    15             ims-prod06.adobelogin.com  KARL STORZ SE & Co. KG
# 2367    23                      scss.adobesc.com  KARL STORZ SE & Co. KG
# 2368    44                     polka.typekit.com  KARL STORZ SE & Co. KG
# 2370    51                      cdn07.boxcdn.net  KARL STORZ SE & Co. KG
# 2371    57             ocsp.quovadisoffshore.com  KARL STORZ SE & Co. KG
# 2372    59             ims-prod07.adobelogin.com  KARL STORZ SE & Co. KG
# 2374    81        smartscreen-prod.microsoft.com  KARL STORZ SE & Co. KG
# 2383   179  ss-prod-ue1-notif-29.aws.adobess.com  KARL STORZ SE & Co. KG
# 2388   219             connect.ffc.adobeoobe.com  KARL STORZ SE & Co. KG
#
# ...

# %% [markdown]
# **The Ministry of Digital Development and Communications**

# %% [markdown]
# * ru - This is the top level domain for the Russian government
# * The Ministry of Digital Development and Communications is a Russian government agency
# * Likely self-signed

# %%
df[df["issuer_O"] == "The Ministry of Digital Development and Communications"]
# Out:
#      index                domain  \
# 2099    49  alt-af.attachmail.ru
#
#                                                     issuer_O  conn_count  \
# 2099  The Ministry of Digital Development and Communications           1
#
#                                                                                                                                                                                                                    historical_ca
# 2099  ['GlobalSign nv-sa (2022-03-01 - 2023-04-02)', 'DigiCert Inc (2021-07-23 - 2022-08-17)', "Let's Encrypt (2019-08-06 - 2019-11-04)", 'GeoTrust Inc. (2014-04-14 - 2017-04-13)', '"Thawte, Inc." (2012-04-03 - 2013-04-03)']

# %% [markdown]
# **Leido**

# %%
df[df["issuer_O"] == "Leido"]
# Out:
#      index                domain issuer_O  conn_count  \
# 2266    68  sccm-ibcm.leidos.com    Leido          14
#
#                                                                                                                  historical_ca
# 2266  ['IdenTrust (2022-03-15 - 2023-03-15)', 'COMODO CA Limited (2013-12-10 - 2016-12-09)', 'SAIC (2013-03-26 - 2015-03-26)']

# %% [markdown]
# **Home Connect GmbH**

# %%
df[df["issuer_O"] == "Home Connect GmbH"]
# Out:
#      index                       domain           issuer_O  conn_count  \
# 2356   330  rna.sdws.homeconnectegw.com  Home Connect GmbH           1
#
#                                 historical_ca
# 2356  Let's Encrypt (2020-07-27 - 2020-10-25)

# %% [markdown]
# **DE Web Works**

# %% [markdown]
# * IT and Web Services Company - https://www.dewebworks.com/

# %%
df[df["issuer_O"] == "DE Web Works"]
# Out:
#      index      domain      issuer_O  conn_count  \
# 2393    10  gdpdev.com  DE Web Works           1
#
#                                  historical_ca
# 2393  "cPanel, Inc." (2019-12-28 - 2020-03-27)
