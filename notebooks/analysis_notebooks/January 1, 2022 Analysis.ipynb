# %%
import pandas as pd

# %%
data_path = "/mnt/chaseproject/uva/kd5eyn/intercept_data/2022-01-01/"
df = pd.read_parquet(data_path + "anon.ssl_20220101_0230-0300-0500.log_pos_intercept.parquet")

# %%
df
# Out:
#     index                                             domain  \
# 0      19                              3RBssjc6.virginia.edu
# 1      21                                    5aOZBG92.vt.edu
# 2      37                              6Q2kLQfg.virginia.edu
# 3      39                                 ols.chaosgroup.com
# 4      53                                   128.143.142.137.
# 5      57                                  stasas.sascms.net
# 6      93                                     Qlog.qcore.com
# 7     129                             ce.cfmedicalcenter.com
# 8     145                              6lIFGFPr.virginia.edu
# 9     146     device.device-management.prod.k8s.pelotime.com
# 10    150                            discovery.syncthing.net
# 11    156                              7J5zxpmX.virginia.edu
# 12    159                                   199.111.191.184.
# 13    161  1.aa64408393602d300fbdcd4a995e4d722ac06a0ff8d7...
# ...

# %%
df = df[df["historical_ca"] != "Unable to find"]

# %%
df
# Out:
#     index                                          domain  \
# 1      21                                 5aOZBG92.vt.edu
# 2      37                           6Q2kLQfg.virginia.edu
# 3      39                              ols.chaosgroup.com
# 6      93                                  Qlog.qcore.com
# 7     129                          ce.cfmedicalcenter.com
# 9     146  device.device-management.prod.k8s.pelotime.com
# 10    150                         discovery.syncthing.net
# 11    156                           7J5zxpmX.virginia.edu
# 15    197                                   www.t2pef.com
# 18    235                         update.blinemedical.com
# 19    245                      discovery-v4.syncthing.net
# 20    310                               grs.dbankcloud.cn
#
#                       issuer_O  conn_count  \
# 1             SomeOrganization         126
# 2             SomeOrganization          36
# 3              N=7Fw6H 2cMYVTs           1
# ...

# %%
print(df[df["domain"] == "ce.cfmedicalcenter.com"]["historical_ca"])
pd.set_option("max_colwidth", None)
df[df["domain"] == "ce.cfmedicalcenter.com"]
# Out:
# 7    ['"GoDaddy.com, Inc." (2022-08-31 - 2023-10-02)', 'GlobalSign nv-sa (2021-08-29 - 2021-12-18)']
# Name: historical_ca, dtype: object
#    index                  domain issuer_O  conn_count  \
# 7    129  ce.cfmedicalcenter.com  Entrust           1
#
#                                                                                      historical_ca
# 7  ['"GoDaddy.com, Inc." (2022-08-31 - 2023-10-02)', 'GlobalSign nv-sa (2021-08-29 - 2021-12-18)']
