# %% [markdown]
# # SSL Interception

# %% [markdown]
# ## Set Up

# %%
import pyspark
from pyspark.sql import SparkSession
import pandas as pd
import os
from tldextract import extract
from pandas.core.frame import DataFrame

# %%
SQLContext = SparkSession.builder.master("local[1]") \
                .appName("session-0") \
                .getOrCreate()
SQLContext.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")

# %%
#Path to parquet file directory
data = "/home/ubuntu/parquet_data/2021-12-28.parquet"
df = SQLContext.read.parquet(data)
df = spark_df.filter(spark_df["anon_orig"] == "uva")

# %%
#df = spark_df.toPandas()
#df

# %% [markdown]
# ## Create Whitelist

# %% [markdown]
# * It's unlikely that SSL Interception proxies will use a public trust CA
# * To get a whitelist of public trust CAs, we filter out validation status == OK
# * Then we save the issuer organization

# %%
df.columns
# Out:
# ['_lpp_ver',
#  'anon_orig',
#  'anon_resp',
#  'cert_chain_fuids',
#  'cipher',
#  'client_cert_chain_fuids',
#  'client_issuer',
#  'client_subject',
#  'curve',
#  'established',
#  'id_orig_h',
#  'id_orig_p',
#  'id_resp_h',
#  'id_resp_p',
#  'issuer',
#  'ja3',
#  'ja3s',
#  'last_alert',
#  'next_protocol',
#  'resumed',
#  'server_name',
#  'subject',
#  'ts',
#  'uid',
#  'validation_status',
#  'version']

# %%
#print(df.iloc[4]["issuer"])
#print(df.iloc[254]["server_name"])

# %%
def get_issuer_org(issuer_str: str):
    if type(issuer_str) == str:
        o_index = issuer_str.find("O=")
        comma_index = issuer_str.find(",", o_index)
        #Get characters starting from after O= and before ,
        org_str = issuer_str[o_index + 2 :comma_index]
        return org_str.replace("\\", "")

def get_domain(server_name_str: str):
    if type(server_name_str) == str:
        domain = extract(server_name_str).domain
        #tld - top level domain
        tld = extract(server_name_str).suffix
        return f"{domain}.{tld}"

# %%
df["issuer_O"] = df["issuer"].apply(lambda issuer_str:get_issuer_org(issuer_str))
df["domain"] = df["server_name"].apply(lambda server_name_str:get_domain(server_name_str))
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 df["issuer_O"] = df["issuer"].apply(lambda issuer_str:get_issuer_org(issuer_str))
#       2 df["domain"] = df["server_name"].apply(lambda server_name_str:get_domain(server_name_str))
#       3 df.head(10)
#
# TypeError: 'Column' object is not callable

# %%
df[df["issuer_O"] == "Cloudflare"]
# Out:
#       _lpp_ver anon_orig anon_resp                          cert_chain_fuids  \
# 970     1.11-1       uva      none  [FKD1Iw1nzWQNC17IJ7, FnSrBA1Q7EEtkxsrZj]
# 1467    1.11-1       uva      none  [FxuovG1Fdg1kSq9DHe, FU8mCz1fbRU9fwX0zg]
# 1809    1.11-1       uva      none  [F73xVj1sU8xjHZDTwh, FvE79T1ANZCPN5WxM9]
# 2330    1.11-1       uva      none  [FHRB2d3PYSOHrXplAd, FkvsU92x7efmBKlEYl]
# 2843    1.11-1       uva      none  [FBIoPt42BmklQEV6Mi, FNlLwJ3fcDfChyrO48]
# 5076    1.11-1       uva      none   [FwaPh13DZSS4vxria8, Fq9vQLYJMJzLBmD9c]
# 5931    1.11-1       uva      none  [Fek4tE2LzIeXJQucv5, FIT3mS2Asmacy6tU7c]
# 6164    1.11-1       uva      none  [FSS4qz1ht68ScsZN57, FCXRHu3mOVUHqQwwvc]
# 7099    1.11-1       uva      none  [F01VAI1PR5HAKRew4a, FBk3vs17qDS5cFHyQf]
# 7853    1.11-1       uva      none   [FxyUhD77J5ruw4aU6, FDI63P2wM51KsG4A5i]
# 7884    1.11-1       uva      none  [Fe50go4FaRSbr8I151, F9BxBm1gVRgq6cpjGi]
# 7913    1.11-1       uva      none  [F7tkFv2UMqzOz85vMj, FcJnf34UMfWQM8G04g]
# 8105    1.11-1       uva      none  [FbXeZX2SVPn7mWLDNd, FMdZwt2CwUToCuuTK6]
# 9249    1.11-1       uva      none  [FMHNd318Q8YQ0KmB19, Fg7FIe4MEvECvQTjXb]
# 9515    1.11-1       uva      none  [F2yx3Z11Qtpq5sqQW7, FRqJic3k0wkN1rfGla]
# 10622   1.11-1       uva      none  [FFZStZ2CaQKCUgcNfa, FMYu0Y3gMcNYDjk2eg]
# 13325   1.11-1       uva      none   [F4xRRf3nFv0JU2ns7d, FNu2EsiiYReNUc6C8]
# 13443   1.11-1       uva      none   [FB5WLE3WbnLOH4Cj29, F4DtR31WgtcK9LFj3]
# 14067   1.11-1       uva      none  [FdASfc1RMB1lwnix4g, FUlL8I3ivoz2YYsS29]
# 14525   1.11-1       uva      none  [F9l0Kc3NF6VM5Zl1Jk, FtqgBu48h03gCda4F1]
# 15843   1.11-1       uva      none   [ForbdZ29dTK1vmaC0l, FyMEaHZo8U5fR1m86]
# 16048   1.11-1       uva      none  [FOy4my3Pj8fc6ExX19, FeasNk44j4WRAKvaRl]
# 17130   1.11-1       uva      none  [FrbD2h3cJwzwUrXxl6, FHGHNd3XZAuKHu7h1k]
# 17549   1.11-1       uva      none  [FCVKJq1Z9Vr2TB8lU3, FwF9Xk3zdCt6L6meqg]
# 17831   1.11-1       uva      none  [FnFNpz4jRho2Mt5Q98, FydnvJ2KSquISz38W6]
# 17938   1.11-1       uva      none  [FXG6cm1ndZulMvm5me, FRUhRw2fYpUs0zvzDf]
# 18612   1.11-1       uva      none  [FCH0Jz1O4kGpcNHzN6, F9sckM3UQJQXx5Gibc]
# 19692   1.11-1       uva      none  [FK2Plj4UtEN7KTYqQc, FNe4tw2i8c6Jxyho8d]
#
#                                               cipher client_cert_chain_fuids  \
# 970          TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 1467         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 1809   TLS_ECDHE_ECDSA_WITH_CHACHA20_POLY1305_SHA256                      []
# 2330         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 2843         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 5076         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 5931         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 6164         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 7099         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 7853         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 7884         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 7913   TLS_ECDHE_ECDSA_WITH_CHACHA20_POLY1305_SHA256                      []
# 8105         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 9249         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 9515         TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 10622        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 13325        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 13443        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 14067  TLS_ECDHE_ECDSA_WITH_CHACHA20_POLY1305_SHA256                      []
# 14525        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 15843        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 16048        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 17130        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 17549        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 17831        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 17938        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 18612        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
# 19692        TLS_ECDHE_ECDSA_WITH_AES_128_GCM_SHA256                      []
#
#       client_issuer client_subject   curve  established  ... next_protocol  \
# 970            None           None  x25519         True  ...            h2
# 1467           None           None  x25519         True  ...            h2
# 1809           None           None    None         True  ...          None
# 2330           None           None  x25519         True  ...            h2
# 2843           None           None  x25519         True  ...            h2
# 5076           None           None  x25519         True  ...            h2
# 5931           None           None  x25519         True  ...            h2
# 6164           None           None  x25519         True  ...            h2
# 7099           None           None  x25519         True  ...            h2
# 7853           None           None  x25519         True  ...            h2
# 7884           None           None  x25519         True  ...            h2
# 7913           None           None    None         True  ...          None
# 8105           None           None  x25519         True  ...      http/1.1
# 9249           None           None  x25519         True  ...            h2
# 9515           None           None  x25519         True  ...          None
# 10622          None           None  x25519         True  ...            h2
# 13325          None           None  x25519         True  ...            h2
# 13443          None           None  x25519         True  ...            h2
# 14067          None           None    None         True  ...          None
# 14525          None           None  x25519         True  ...            h2
# 15843          None           None  x25519         True  ...          None
# 16048          None           None  x25519         True  ...            h2
# 17130          None           None  x25519         True  ...            h2
# 17549          None           None  x25519         True  ...            h2
# 17831          None           None  x25519         True  ...            h2
# 17938          None           None  x25519         True  ...          None
# 18612          None           None  x25519         True  ...          None
# 19692          None           None  x25519         True  ...            h2
#
#        resumed                                server_name  \
# 970      False                  metadata.provider.plex.tv
# 1467     False                            otf.zendesk.com
# 1809     False                    www.cochranelibrary.com
# 2330     False                       router.infolinks.com
# 2843     False                         browser-update.org
# 5076     False                       static.getclicky.com
# 5931     False                      kessel-api.parsec.app
# 6164     False                          p.adsymptotic.com
# 7099     False  amna01mstra8s42prod.dxcloud.episerver.net
# 7853     False                              img.webmd.com
# 7884     False                            i.emlfiles4.com
# 7913     False                       registry.yarnpkg.com
# 8105     False                   tracker.adreadyclick.com
# 9249     False                      update.avgbrowser.com
# 9515     False               s3-prod.modernhealthcare.com
# 10622    False                    www.threadsmagazine.com
# 13325    False                      wh.consumersource.com
# 13443    False                 redirect.advconversion.com
# 14067    False                          www.cambridge.org
# 14525    False                      latency.discord.media
# 15843    False                          se3v5tjfff3aet.me
# 16048    False                       rt3004.infolinks.com
# 17130    False                         static.stacker.com
# 17549    False                            pre.glotgrx.com
# 17831    False                               api.radar.io
# 17938    False                         registry.npmjs.org
# 18612    False                       www.northerntool.com
# 19692    False                   siteimproveanalytics.com
#
#                                                  subject  \
# 970    CN=plex.tv,O=Cloudflare\, Inc.,L=San Francisco...
# 1467   CN=otf.zendesk.com,O=Cloudflare\, Inc.,L=San F...
# 1809   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 2330   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 2843   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 5076   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 5931   CN=parsec.app,O=Cloudflare\, Inc.,L=San Franci...
# 6164   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 7099   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 7853   CN=img.webmd.com,O=Cloudflare\, Inc.,L=San Fra...
# 7884   CN=i.emlfiles4.com,O=Cloudflare\, Inc.,L=San F...
# 7913   CN=registry.yarnpkg.com,O=Cloudflare\, Inc.,L=...
# 8105   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 9249   CN=avgbrowser.com,O=Cloudflare\, Inc.,L=San Fr...
# 9515   CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 10622  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 13325  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 13443  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 14067  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 14525  CN=discord.media,O=Cloudflare\, Inc.,L=San Fra...
# 15843  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 16048  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 17130  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 17549  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 17831  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 17938  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
# 18612  CN=northerntool.com,O=Cloudflare\, Inc.,L=San ...
# 19692  CN=sni.cloudflaressl.com,O=Cloudflare\, Inc.,L...
#
#                                 ts                 uid validation_status  \
# 970    2021-12-28T14:31:30.760917Z  CWaZvS2Ms7ytHr6BP1                ok
# 1467   2021-12-28T14:32:16.174148Z  Cxv9g34x5CWIw3BDji                ok
# 1809   2021-12-28T14:32:46.347308Z   C4oGtM4je9z20iy47                ok
# 2330   2021-12-28T14:33:32.219378Z   C6KsalzVPtJqdUgfe                ok
# 2843   2021-12-28T14:34:20.652952Z   CKW1Qm6A6raJmli4b                ok
# 5076   2021-12-28T14:37:33.053533Z   C6jZGO3slXobNkuJb                ok
# 5931   2021-12-28T14:38:49.365574Z  Cc3JYa1FOV8qwln1V8                ok
# 6164   2021-12-28T14:39:09.665795Z  CJkPga2QInSYya4v7a                ok
# 7099   2021-12-28T14:40:35.260813Z  C2zzCm4Etnre7E2uW8                ok
# 7853   2021-12-28T14:41:48.763554Z  Cgdudt1JfHj5dmiUwk                ok
# 7884   2021-12-28T14:41:51.792534Z  CfchYv101PkwiMS9i3                ok
# 7913   2021-12-28T14:41:54.680245Z  CcjYtf2Yo3Rh0WKWP1                ok
# 8105   2021-12-28T14:42:10.510333Z  CJCWlL1hToitOpHFm1                ok
# 9249   2021-12-28T14:43:54.776258Z  CyWFhk1cYPdabsJaJd                ok
# 9515   2021-12-28T14:44:19.035863Z   CnWqn3DEhmUZF0xt8                ok
# 10622  2021-12-28T14:45:53.294119Z  C3wRU81vvyEWV35Lof                ok
# 13325  2021-12-28T14:49:55.778885Z  Ct3gjT3ZDQurOExeSe                ok
# 13443  2021-12-28T14:50:07.546958Z  Cba9Rf3aMgaFaqZXye                ok
# 14067  2021-12-28T14:51:03.190901Z  CRrNe31xTWyi3euTye                ok
# 14525  2021-12-28T14:51:44.654944Z  CXb1hG3KibYxDR8BFb                ok
# 15843  2021-12-28T14:53:41.208062Z  CQaCiQ2erUCftuGFFd                ok
# 16048  2021-12-28T14:53:58.828706Z   C0zLv3NwvorowkN7k                ok
# 17130  2021-12-28T14:55:38.210802Z  CPeHep4GQmlyaoWaz8                ok
# 17549  2021-12-28T14:56:12.463881Z  CCmcyV2W1GWhXyuug1                ok
# 17831  2021-12-28T14:56:37.417333Z  C8pw3m1uqh51y3Nd33                ok
# 17938  2021-12-28T14:56:45.692563Z   CwGYQsZ4zWhBSVEii                ok
# 18612  2021-12-28T14:57:45.000795Z    CrgjPLXkHkP89GWI                ok
# 19692  2021-12-28T14:59:21.873688Z   CzaPooqKYN5g6BTHd                ok
#
#       version    issuer_O                    domain
# 970    TLSv12  Cloudflare                   plex.tv
# 1467   TLSv12  Cloudflare               zendesk.com
# 1809   TLSv12  Cloudflare       cochranelibrary.com
# 2330   TLSv12  Cloudflare             infolinks.com
# 2843   TLSv12  Cloudflare        browser-update.org
# 5076   TLSv12  Cloudflare             getclicky.com
# 5931   TLSv12  Cloudflare                parsec.app
# 6164   TLSv12  Cloudflare           adsymptotic.com
# 7099   TLSv12  Cloudflare             episerver.net
# 7853   TLSv12  Cloudflare                 webmd.com
# 7884   TLSv12  Cloudflare             emlfiles4.com
# 7913   TLSv12  Cloudflare               yarnpkg.com
# 8105   TLSv12  Cloudflare          adreadyclick.com
# 9249   TLSv12  Cloudflare            avgbrowser.com
# 9515   TLSv12  Cloudflare      modernhealthcare.com
# 10622  TLSv12  Cloudflare       threadsmagazine.com
# 13325  TLSv12  Cloudflare        consumersource.com
# 13443  TLSv12  Cloudflare         advconversion.com
# 14067  TLSv12  Cloudflare             cambridge.org
# 14525  TLSv12  Cloudflare             discord.media
# 15843  TLSv12  Cloudflare         se3v5tjfff3aet.me
# 16048  TLSv12  Cloudflare             infolinks.com
# 17130  TLSv12  Cloudflare               stacker.com
# 17549  TLSv12  Cloudflare               glotgrx.com
# 17831  TLSv12  Cloudflare                  radar.io
# 17938  TLSv12  Cloudflare                 npmjs.org
# 18612  TLSv12  Cloudflare          northerntool.com
# 19692  TLSv12  Cloudflare  siteimproveanalytics.com
#
# [28 rows x 28 columns]

# %%
print(df.iloc[5]["issuer"])
# Out:
# None

# %%
df_ok = df[df["validation_status"] == "ok"]
df_orgs = df_ok.groupby(["issuer_O"])["server_name"].agg("count").reset_index(name="count").sort_values(by="count", ascending=False)
df_orgs.head(10)
# Out:
#                      issuer_O  count
# 9                DigiCert Inc   2613
# 22      Microsoft Corporation   1574
# 2                      Amazon   1392
# 27     Starfield Technologies    564
# 26            Sectigo Limited    380
# 14                GoDaddy.com    363
# 3                  Apple Inc.    336
# 16  Google Trust Services LLC    180
# 13           GlobalSign nv-sa    164
# 11                    Entrust    140

# %%
def gen_whitelist(whitelist_path: str, df_orgs: pd.core.frame.DataFrame):
    whitelist_file = open(whitelist_path, "r+")
    whitelist_orgs = set(whitelist_file.read().splitlines())
    for org in df_orgs["issuer_O"]:
        if org not in whitelist_orgs:
            whitelist_orgs.add(org)
            whitelist_file.write(org + "\n")
    return whitelist_orgs

# %%
whitelist = gen_whitelist("whitelist.txt", df_orgs)

# %% [markdown]
# ## Parse for Unable to Get Local Certificate

# %%
def get_validation_status_df(df: DataFrame, validation_status: str):
    return df[df["validation_status"] == validation_status]

# %%
df_unable = get_validation_status_df(df, "unable to get local issuer certificate")
df_unable
# Out:
#       _lpp_ver anon_orig anon_resp                          cert_chain_fuids  \
# 25      1.11-1       uva      none   [Ff9I0d2ou2pEX2OS66, Fk1k8NmDbTbx6t9Od]
# 26      1.11-1       uva      none  [FxGxlv1eMW6vsQ0737, F2mekw14U0T6bYWtQi]
# 27      1.11-1       uva      none   [FPNDTsyjgaXMURfFh, FbaxTr3jwqJQ0r1FWg]
# 39      1.11-1       uva      none   [Fxqs6p1GAreWnUzv8, FFOBT02fcAN6whxE66]
# 41      1.11-1       uva      none   [FIAgL64Te7S2jBVpn1, FHD0QYUsX1ANpU4A2]
# ...        ...       ...       ...                                       ...
# 20049   1.11-1       uva      none   [FjpSPm3k0xozrHTvr5, FUATDW2TLRu8uTvBc]
# 20067   1.11-1       uva      none  [FAJ7FC13G0i0Cr1Je8, F9NTGa3tSRWXGterTk]
# 20068   1.11-1       uva      none   [FTaD2e1Bf4mJxO0oi3, FnEV1OvmmRoJUoUSk]
# 20071   1.11-1       uva      none   [FnQATK1Sxn7HCgbx1d, FVN7wYxipGNTOjXc9]
# 20095   1.11-1       uva      none   [FfHKA31RgOF7MCeFFb, FEPtwoXIwEQD7DAh4]
#
#                                         cipher client_cert_chain_fuids  \
# 25       TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 26     TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384                      []
# 27       TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 39       TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 41       TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# ...                                        ...                     ...
# 20049    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 20067    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 20068    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256                      []
# 20071    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384                      []
# 20095  TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384                      []
#
#       client_issuer client_subject      curve  established  ... next_protocol  \
# 25             None           None  secp384r1         True  ...          None
# 26             None           None  secp384r1         True  ...            h2
# 27             None           None  secp384r1         True  ...          None
# 39             None           None     x25519         True  ...            h2
# 41             None           None  secp384r1         True  ...          None
# ...             ...            ...        ...          ...  ...           ...
# 20049          None           None     x25519         True  ...            h2
# 20067          None           None  secp384r1         True  ...          None
# 20068          None           None     x25519         True  ...            h2
# 20071          None           None  secp384r1         True  ...          None
# 20095          None           None  secp384r1         True  ...            h2
#
#        resumed                            server_name  \
# 25       False          v10.events.data.microsoft.com
# 26       False  array802.prod.do.dsp.mp.microsoft.com
# 27       False          v10.events.data.microsoft.com
# 39       False        settings-win.data.microsoft.com
# 41       False       us-v20.events.data.microsoft.com
# ...        ...                                    ...
# 20049    False        settings-win.data.microsoft.com
# 20067    False          v10.events.data.microsoft.com
# 20068    False        settings-win.data.microsoft.com
# 20071    False          v10.events.data.microsoft.com
# 20095    False  array613.prod.do.dsp.mp.microsoft.com
#
#                                                  subject  \
# 25     CN=*.events.data.microsoft.com,OU=WSE,O=Micros...
# 26     CN=*.prod.do.dsp.mp.microsoft.com,OU=DSP,O=Mic...
# 27     CN=*.events.data.microsoft.com,OU=WSE,O=Micros...
# 39     CN=settings-win.data.microsoft.com,OU=WSE,O=Mi...
# 41     CN=*.events.data.microsoft.com,OU=WSE,O=Micros...
# ...                                                  ...
# 20049  CN=settings-win.data.microsoft.com,OU=WSE,O=Mi...
# 20067  CN=*.events.data.microsoft.com,OU=WSE,O=Micros...
# 20068  CN=settings-win.data.microsoft.com,OU=WSE,O=Mi...
# 20071  CN=*.events.data.microsoft.com,OU=WSE,O=Micros...
# 20095  CN=*.prod.do.dsp.mp.microsoft.com,OU=DSP,O=Mic...
#
#                                 ts                 uid  \
# 25     2021-12-28T14:30:00.744078Z  CkABp430NRXBhRd1O5
# 26     2021-12-28T14:30:00.708941Z  C0jph610J1pMdHabL1
# 27     2021-12-28T14:30:01.034601Z   Cas9McfM0Pe1s8cwc
# 39     2021-12-28T14:30:02.370812Z  Cl6j0G4Vqaaaw1xxRl
# 41     2021-12-28T14:30:02.170327Z   CfB8j12llTlJ4tB93
# ...                            ...                 ...
# 20049  2021-12-28T14:59:52.604423Z   CAuLKTQks6FsFsHD1
# 20067  2021-12-28T14:59:54.470599Z  CFGPSo4WVFNgZstSLg
# 20068  2021-12-28T14:59:55.173665Z  CDu5lL3UlbAnDrVsg5
# 20071  2021-12-28T14:59:54.843187Z  CfMk1L35ujtR276Ys6
# 20095  2021-12-28T14:59:56.362708Z   C4JfSNw7VgeemPOCb
#
#                             validation_status version               issuer_O  \
# 25     unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 26     unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 27     unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 39     unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 41     unable to get local issuer certificate  TLSv12  Microsoft Corporation
# ...                                       ...     ...                    ...
# 20049  unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 20067  unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 20068  unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 20071  unable to get local issuer certificate  TLSv12  Microsoft Corporation
# 20095  unable to get local issuer certificate  TLSv12  Microsoft Corporation
#
#               domain
# 25     microsoft.com
# 26     microsoft.com
# 27     microsoft.com
# 39     microsoft.com
# 41     microsoft.com
# ...              ...
# 20049  microsoft.com
# 20067  microsoft.com
# 20068  microsoft.com
# 20071  microsoft.com
# 20095  microsoft.com
#
# [1770 rows x 28 columns]

# %%
df_unable = df_unable[~(df_unable["issuer_O"].isin(whitelist))]
df_unable
# Out:
#       _lpp_ver anon_orig anon_resp                          cert_chain_fuids  \
# 927     1.11-1       uva      none  [FnSGUk3C6p3QNMcnqk, Ft5ylG1S8KmAGa0n8h]
# 2034    1.11-1       uva      none   [FKuJgM3xjnWajqcf63, FJVfTu4SwVNqusYei]
# 2284    1.11-1       uva      none  [FBF7Cb26vtA2WdTvUa, Fgebvk1YvZobcMTSSd]
# 2296    1.11-1       uva      none   [FTHm8I2CKCphJL8yLe, F6CxPILpLM2280AP2]
# 3533    1.11-1       uva      none  [FEu2Ta2vwevTQ8cl6k, FuMF9v4eSWs9KOKXXf]
# 4150    1.11-1       uva      none                       [Fee6JsG2i6pGvX8Cl]
# 4374    1.11-1       uva      none  [FjZU9b18edGCVjMyAk, Fkr3la252R3rbaO5Ef]
# 8244    1.11-1       uva      none    [FlKLeHDPtgLRTrvFg, FMOQ0XUQRkOSwXEF6]
# 8965    1.11-1       uva      none   [Fax6kqb6YTtJM2hT2, F16sDK1Fih1h73Q4d6]
# 9281    1.11-1       uva      none                      [Feo4de4yOfPUwuoFql]
# 9703    1.11-1       uva      none  [FLBil62ATn492OAe85, FavmuL23L3DfNY2pb1]
# 10619   1.11-1       uva      none                      [F9OmCI3F23X3B6TcA2]
# 10862   1.11-1       uva      none  [FJDitU3qVbb9AkuU97, FYAwWg1s6CSCbvVuLa]
# 12064   1.11-1       uva      none                      [FL5VHO3pFx9dseicy2]
# 13319   1.11-1       uva      none                      [FBH2s52krlTGnc3glb]
# 14279   1.11-1       uva      none                        [FJCsXqdL7c3LJLKE]
# 14457   1.11-1       uva      none                      [FFdljL2Bb2KmNijK7e]
# 14824   1.11-1       uva      none                      [Fp7Obn2qVOpZT6LUo8]
# 15015   1.11-1       uva      none  [FBZeuq2jhVGQ1FP755, FwJQvS1KixjytIkZUd]
# 16190   1.11-1       uva      none                      [Fi4aTJ2R5uvcXq1hj9]
# 16340   1.11-1       uva      none                       [FM5Nxm0Ubhz5AkXr4]
# 16663   1.11-1       uva      none    [FcqNaTUVEJuaEWWai, F7pw4BSXSX1UCSKM7]
# 17712   1.11-1       uva      none                      [FQbT0s3hiPFAK6EUAd]
# 18750   1.11-1       uva      none    [Fscdgf4rOK7bYr0Ic1, FxsQnNF4cptxH9n7]
# 18902   1.11-1       uva      none                      [Fm8ydd1KGr4JJWRvYb]
# 19139   1.11-1       uva      none                      [FU3Aco4hyBmwIIuDGd]
# 19857   1.11-1       uva      none                      [F0Xoei2tvcpk1W10bk]
# 20006   1.11-1       uva      none  [FbpI8w12pumNt9lYnb, FjcCrc1JCw0GfSD9kl]
#
#                                         cipher  \
# 927      TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 2034        TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA
# 2284     TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 2296       TLS_DHE_RSA_WITH_AES_256_GCM_SHA384
# 3533           TLS_RSA_WITH_AES_128_GCM_SHA256
# 4150   TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384
# 4374     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 8244     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 8965     TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 9281   TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384
# 9703     TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 10619             TLS_RSA_WITH_AES_128_CBC_SHA
# 10862    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 12064       TLS_ECDHE_RSA_WITH_AES_128_CBC_SHA
# 13319  TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384
# 14279    TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384
# 14457    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 14824    TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384
# 15015      TLS_DHE_RSA_WITH_AES_256_GCM_SHA384
# 16190    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 16340  TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384
# 16663    TLS_ECDHE_RSA_WITH_AES_256_CBC_SHA384
# 17712  TLS_ECDHE_ECDSA_WITH_AES_256_GCM_SHA384
# 18750    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 18902    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 19139    TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384
# 19857    TLS_ECDHE_RSA_WITH_AES_128_GCM_SHA256
# 20006          TLS_RSA_WITH_AES_128_GCM_SHA256
#
#                                  client_cert_chain_fuids  \
# 927                                                   []
# 2034                                                  []
# 2284                                [F9Uc4N1ieWArXgcx0k]
# 2296                                                  []
# 3533   [FjJBYm2NyLcRuqA0ng, FjJbMX2b55Ix5hfnE2, FxupI...
# 4150                                                  []
# 4374                                                  []
# 8244                                [Fia64r31GfFcadU2rl]
# 8965                                 [FlDmSaEWbHgoWrKp2]
# 9281                                                  []
# 9703                                                  []
# 10619                                                 []
# 10862                               [Fshjex4aA9IHiaqqx2]
# 12064           [FTF5xH3eD9GhvkyLph, FZFEYf37cDH04A1mQe]
# 13319                                                 []
# 14279                                                 []
# 14457                                                 []
# 14824                                [F41aSfDVJnqSCklW5]
# 15015                                                 []
# 16190  [FjN6su3miqkefNxS67, FBKvOhxICuH2nNfc6, FHsyle...
# 16340                                                 []
# 16663                                                 []
# 17712                                                 []
# 18750           [FgGcJ91Eabf5DKWX6j, FdcX3p45ZKcjOTRi8i]
# 18902  [FXf3I817wZZguGcMjd, FisHXX1CG3gxpaR8Ri, FOLqU...
# 19139                                                 []
# 19857                                                 []
# 20006  [FKXsqb49bcXRTCnPdb, Fsrfon2PXkNd3TTrGb, Fb2uU...
#
#                                            client_issuer  \
# 927                                                 None
# 2034                                                None
# 2284   emailAddress=wDCSb1nb@redhat.com,CN=EfA 4V6 5d...
# 2296                                                None
# 3533   CN=5HMMQusZR 24o 6CXE Tu5 1V,OU=RSA CBSD Mfr C...
# 4150                                                None
# 4374                                                None
# 8244   CN=4i25mTSax 1jUgVaec9X 3jjsr 1IlTtQ 2GVU1Y 1V...
# 8965   CN=4i25mTSax 1jUgVaec9X 3jjsr 1IlTtQ 2GVU1Y 1V...
# 9281                                                None
# 9703                                                None
# 10619                                               None
# 10862  CN=4i25mTSax 1jUgVaec9X 3jjsr 1IlTtQ 2GVU1Y 1V...
# 12064                       C=US,O=ConnectVirginia,CN=1V
# 13319                                               None
# 14279                                               None
# 14457                                               None
# 14824  ST=Tokyo,OU=Remote Service,O=RICOH COMPANY\,LT...
# 15015                                               None
# 16190  emailAddress=6DdL0TeH@corelight.Jt0,CN=32XZ0ds...
# 16340                                               None
# 16663                                               None
# 17712                                               None
# 18750              CN=5f0hX7B 3cJbGlT1 5lja1WF 1V 18 5-7
# 18902  emailAddress=6DdL0TeH@corelight.Jt0,CN=32XZ0ds...
# 19139                                               None
# 19857                                               None
# 20006  CN=5HMMQusZR 24o 6CXE Tu5 1V,OU=RSA CBSD Mfr C...
#
#                                           client_subject      curve  \
# 927                                                 None  secp256r1
# 2034                                                None  secp256r1
# 2284             CN=39JXLSpu-65DQ-1kjr-4BuJ-3NGEF6A0NwWg  secp256r1
# 2296                                                None       None
# 3533   CN=1Tm5Y1wqLq7:4xrGjCOm7n2W,OU=WInnForum CBSD ...       None
# 4150                                                None     x25519
# 4374                                                None  secp256r1
# 8244     CN=7qKBwJJVYfZrYADQAymBWuGvqLIXKYxr,O=JumpCloud  secp256r1
# 8965     CN=jyyGfFCivvjw0JXBerOxLmwBdVZIk4hi,O=JumpCloud  secp256r1
# 9281                                                None     x25519
# 9703                                                None     x25519
# 10619                                               None       None
# 10862    CN=hdDMujQtNDFR6JIQNjiICceVvISZJdgb,O=JumpCloud  secp256r1
# 12064                           CN=1yeTMaVn.virgRzFW.1rB  secp256r1
# 13319                                               None     x25519
# 14279                                               None  secp384r1
# 14457                                               None  secp256r1
# 14824  ST=Tokyo,OU=Remote Service,O=RICOH COMPANY\,LT...  secp256r1
# 15015                                               None       None
# 16190  emailAddress=6DdL0TeH@corelight.Jt0,CN=4b-6c-e...  secp256r1
# 16340                                               None     x25519
# 16663                                               None  secp384r1
# 17712                                               None     x25519
# 18750                           CN=1mOHT-2fwm8,O=Extreme  secp256r1
# 18902  emailAddress=6DdL0TeH@corelight.Jt0,CN=4b-6c-e...  secp256r1
# 19139                                               None     x25519
# 19857                                               None  secp256r1
# 20006  CN=1Tm5Y1wqLq7:83QO5aVcFia3,OU=WInnForum CBSD ...       None
#
#        established  ... next_protocol  resumed  \
# 927           True  ...          None    False
# 2034          True  ...          None    False
# 2284          True  ...          None    False
# 2296          True  ...          None    False
# 3533          True  ...      http/1.1    False
# 4150          True  ...          None    False
# 4374          True  ...          None    False
# 8244          True  ...          None    False
# 8965          True  ...          None    False
# 9281          True  ...          None    False
# 9703          True  ...          None    False
# 10619        False  ...          None    False
# 10862         True  ...          None    False
# 12064         True  ...          None    False
# 13319         True  ...          None    False
# 14279         True  ...          None    False
# 14457         True  ...          None    False
# 14824         True  ...          None    False
# 15015         True  ...          None    False
# 16190         True  ...          None    False
# 16340         True  ...          None    False
# 16663         True  ...          None    False
# 17712         True  ...          None    False
# 18750         True  ...          None    False
# 18902         True  ...          None    False
# 19139         True  ...          None    False
# 19857        False  ...          None    False
# 20006         True  ...      http/1.1    False
#
#                             server_name  \
# 927                scribe.logs.roku.com
# 2034             api-global.netflix.com
# 2284                               None
# 2296   epicsfd.connecticutchildrens.org
# 3533                  stasas.sascms.net
# 4150                               None
# 4374             api-global.netflix.com
# 8244                agent.jumpcloud.com
# 8965                agent.jumpcloud.com
# 9281                               None
# 9703          sccmsite.rams.adp.vcu.edu
# 10619         crreceiver.softdev.spb.ru
# 10862               agent.jumpcloud.com
# 12064          edge.connectvirginia.org
# 13319                              None
# 14279               bmecmg.cloudapp.net
# 14457                              None
# 14824                              None
# 15015         sfd.et1127.epichosted.com
# 16190          release.api.corelight.io
# 16340                              None
# 16663         myuvacmgprod.cloudapp.net
# 17712                              None
# 18750       devices.extremenetworks.com
# 18902          release.api.corelight.io
# 19139                              None
# 19857           gld.push.samsungosp.com
# 20006                 stasas.sascms.net
#
#                                                  subject  \
# 927    CN=scribe.logs.roku.com,O=Roku\, Inc.,L=San Jo...
# 2034   CN=api.netflix.com,O=Netflix\, Inc.,L=Los Gato...
# 2284   emailAddress=wDCSb1nb@redhat.com,CN=4B3LrxyIGB...
# 2296   CN=epicsfd.connecticutchildrens.org,OU=CAREQUA...
# 3533   CN=sas.sascms.net,OU=CommScope SAS Certificate...
# 4150                       O=Infoblox,ST=California,C=US
# 4374   CN=api.netflix.com,O=Netflix\, Inc.,L=Los Gato...
# 8244   CN=agent.jumpcloud.com,OU=DevOps,O=JumpCloud,S...
# 8965   CN=agent.jumpcloud.com,OU=DevOps,O=JumpCloud,S...
# 9281                       O=Infoblox,ST=California,C=US
# 9703                        CN=SCCMSITE.RAMS.adp.vcu.edu
# 10619                                               None
# 10862  CN=agent.jumpcloud.com,OU=DevOps,O=JumpCloud,S...
# 12064                        CN=edge.connectvirginia.org
# 13319                      O=Infoblox,ST=California,C=US
# 14279                             CN=BMECMG.CLOUDAPP.NET
# 14457                                CN=20QdtgiXUz2aa6N3
# 14824  ST=Tokyo,OU=Remote Service,O=RICOH COMPANY\,LT...
# 15015  CN=sfd.et1127.epichosted.com,OU=CAREQUALITY,O=...
# 16190  emailAddress=6DdL0TeH@corelight.Jt0,CN=release...
# 16340                      O=Infoblox,ST=California,C=US
# 16663                       CN=myuvacmgprod.cloudapp.net
# 17712                      O=Infoblox,ST=California,C=US
# 18750  CN=devices.extremenetworks.com,OU=EXOL,O=Inter...
# 18902  emailAddress=6DdL0TeH@corelight.Jt0,CN=release...
# 19139  emailAddress=2XtxRsrz@vmware.com,CN=*.49.3cGJw...
# 19857                                               None
# 20006  CN=sas.sascms.net,OU=CommScope SAS Certificate...
#
#                                 ts                 uid  \
# 927    2021-12-28T14:31:26.533336Z  CXg0Mn1tnfheetmkzf
# 2034   2021-12-28T14:33:05.139184Z   CAAcDcULmTO6yj26i
# 2284   2021-12-28T14:33:28.241852Z  CW1y881PeKreXoGvxc
# 2296   2021-12-28T14:33:30.095271Z   CMp0pc8W8pmVP4itf
# 3533   2021-12-28T14:35:20.932834Z  C0hHwO3JOTg3byCjHj
# 4150   2021-12-28T14:36:16.561276Z  CAEtxn2WB83pPDG7ij
# 4374   2021-12-28T14:36:34.932830Z  CITBdq2KuJIGCEbPv4
# 8244   2021-12-28T14:42:24.264742Z   CHLTFp7kzT2tpjeo7
# 8965   2021-12-28T14:43:29.928148Z  CqWQcP2acOSc1ykrmg
# 9281   2021-12-28T14:43:56.624702Z   CxJIBonCb7AMwWyBg
# 9703   2021-12-28T14:44:36.604552Z  CG4xYZ37rUylNXtuy1
# 10619  2021-12-28T14:45:47.977255Z  CZtp9p2BGFZWcury01
# 10862  2021-12-28T14:46:10.686982Z  CNiDnx4YOMnvbwVGkg
# 12064  2021-12-28T14:48:01.379611Z    CyIqctJ7lKVad9C2
# 13319  2021-12-28T14:49:56.201508Z   C5qlUMbYvh46UUVkh
# 14279  2021-12-28T14:51:21.907052Z   Ca44kVEhaVkT99f8a
# 14457  2021-12-28T14:51:36.970678Z  CDSCZQ2x26DL3uxCM2
# 14824  2021-12-28T14:52:10.301947Z   C9zi72RIwM6DpSZWj
# 15015  2021-12-28T14:52:28.569053Z  CPP0GK3LwFbHSW4pQd
# 16190  2021-12-28T14:54:11.148490Z   CrwD6xgsUwvjKz1N8
# 16340  2021-12-28T14:54:26.123572Z  Cd8f6y3Jc2DFbqJev3
# 16663  2021-12-28T14:54:54.799600Z  CaxYPp476Foj2XtTPi
# 17712  2021-12-28T14:56:26.021933Z  CxQhiw4ZXDyBLHv7C1
# 18750  2021-12-28T14:57:57.856662Z    CXX7ZUntfnJkppRt
# 18902  2021-12-28T14:58:11.116783Z   CA4d9TBzAXGGFYiOk
# 19139  2021-12-28T14:58:30.619429Z  CDdmNv2DJPtmFc2JAj
# 19857  2021-12-28T14:59:31.587829Z  CeY5ZL2bPwVulMyCh1
# 20006  2021-12-28T14:59:46.318628Z   CZZEZLX8eQvkehFR4
#
#                             validation_status version  \
# 927    unable to get local issuer certificate  TLSv12
# 2034   unable to get local issuer certificate  TLSv10
# 2284   unable to get local issuer certificate  TLSv12
# 2296   unable to get local issuer certificate  TLSv12
# 3533   unable to get local issuer certificate  TLSv12
# 4150   unable to get local issuer certificate  TLSv12
# 4374   unable to get local issuer certificate  TLSv12
# 8244   unable to get local issuer certificate  TLSv12
# 8965   unable to get local issuer certificate  TLSv12
# 9281   unable to get local issuer certificate  TLSv12
# 9703   unable to get local issuer certificate  TLSv12
# 10619  unable to get local issuer certificate  TLSv10
# 10862  unable to get local issuer certificate  TLSv12
# 12064  unable to get local issuer certificate  TLSv12
# 13319  unable to get local issuer certificate  TLSv12
# 14279  unable to get local issuer certificate  TLSv12
# 14457  unable to get local issuer certificate  TLSv12
# 14824  unable to get local issuer certificate  TLSv12
# 15015  unable to get local issuer certificate  TLSv12
# 16190  unable to get local issuer certificate  TLSv12
# 16340  unable to get local issuer certificate  TLSv12
# 16663  unable to get local issuer certificate  TLSv12
# 17712  unable to get local issuer certificate  TLSv12
# 18750  unable to get local issuer certificate  TLSv12
# 18902  unable to get local issuer certificate  TLSv12
# 19139  unable to get local issuer certificate  TLSv12
# 19857  unable to get local issuer certificate  TLSv12
# 20006  unable to get local issuer certificate  TLSv12
#
#                                                 issuer_O  \
# 927                                                 Roku
# 2034                                             Netflix
# 2284                                             Red Hat
# 2296                                          EMR Direct
# 3533                                           CommScope
# 4150                                            Infoblox
# 4374                                             Netflix
# 8244                                           JumpCloud
# 8965                                           JumpCloud
# 9281                                            Infoblox
# 9703     N=4Iz 4s3588P 1lbnu,DC=RAMS,DC=adp,DC=vcu,DC=ed
# 10619                                               None
# 10862                                          JumpCloud
# 12064                                    ConnectVirginia
# 13319                                           Infoblox
# 14279        N=283Lr0 4zOfx 6Nwi 1V,DC=BartonMalow,DC=co
# 14457                                           N=1*46zE
# 14824                                      RICOH COMPANY
# 15015                                         EMR Direct
# 16190                                          Corelight
# 16340                                           Infoblox
# 16663         N=4p-14i-1V,DC=eservices,DC=virginia,DC=ed
# 17712                                           Infoblox
# 18750  N=5f0hX7B 3cJbGlT1 66V 5lja1WF 1V,DC=corp,DC=e...
# 18902                                          Corelight
# 19139                                             VMware
# 19857                                               None
# 20006                                          CommScope
#
#                          domain
# 927                    roku.com
# 2034                netflix.com
# 2284                       None
# 2296   connecticutchildrens.org
# 3533                 sascms.net
# 4150                       None
# 4374                netflix.com
# 8244              jumpcloud.com
# 8965              jumpcloud.com
# 9281                       None
# 9703                    vcu.edu
# 10619                    spb.ru
# 10862             jumpcloud.com
# 12064       connectvirginia.org
# 13319                      None
# 14279              cloudapp.net
# 14457                      None
# 14824                      None
# 15015            epichosted.com
# 16190              corelight.io
# 16340                      None
# 16663              cloudapp.net
# 17712                      None
# 18750       extremenetworks.com
# 18902              corelight.io
# 19139                      None
# 19857            samsungosp.com
# 20006                sascms.net
#
# [28 rows x 28 columns]
